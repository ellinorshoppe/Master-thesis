# %% [markdown]
# # UNIFI library for processing of MS-spectra
# Two new libraries for halogenated and non-halogenated compounds will be made to make sure that all peaks are processed correctly and more efficiently for the processing of the spectra.

# %%
import pandas as pd
import numpy as np

import pickle

# %%
#Import the data
with open('/Users/elli/Library/CloudStorage/OneDrive-Kruvelab/Ellinor - Master thesis/Code/Experimental_work/2025-04-25_experimental_analysis_compounds.pkl', 'rb') as f:
    actives = pickle.load(f)

# %%
actives
# Out:
#                               name         cas  \
# 0                    Indene (mass)     95-13-6
# 1         alpha-Tetralone (volume)    529-34-0
# 2        4-Chlorophenyl isocyanate    104-12-1
# 3             2-Chloroacetophenone    532-27-4
# 4              cis-Stilbene (mass)    645-49-8
# ..                             ...         ...
# 94               Triphenylethylene     58-72-0
# 95                        o,p'-DDT    789-02-6
# 96  Tris(dimethylphenyl)-phosphate  25155-23-1
# 97      2,4-Dimethylaniline (mass)     95-68-1
# 98    Phenyl isothiocyanate (mass)    103-72-0
#
#                               section nr.ahr sr.mmp amount unit  \
# 0                Group Kálmán J Szabó    1.0    NaN  250.0    g
# 1                  Group Joseph Samec    1.0    0.0  100.0   ml
# 2                Group Kálmán J Szabó    NaN    1.0  100.0    g
# 3                Group Kálmán J Szabó    1.0    0.0  100.0    g
# 4                  Group Joseph Samec    1.0    0.0    5.0    g
# ..                                ...    ...    ...    ...  ...
# 94               Group Pher Andersson    NaN    1.0    5.0    g
# 95  ACESo, Contaminant Chemistry Unit    0.0    1.0      1   g
# 96  ACESo, Contaminant Chemistry Unit    1.0    NaN    0.1  ml
# 97               Group Pher Andersson    1.0    0.0  100.0    g
# 98               Group Pher Andersson    NaN    1.0  100.0    g
#
#                        building   floor           room  ... HBA HBD  \
# 0   Arrheniuslaboratoriet Hus A  Plan 5  A516 i övrigt  ...   0   0
# 1   Arrheniuslaboratoriet Hus A  Plan 6           A659  ...   1   0
# 2   Arrheniuslaboratoriet Hus A  Plan 5  A516 i övrigt  ...   2   0
# 3   Arrheniuslaboratoriet Hus A  Plan 5  A516 i övrigt  ...   1   0
# 4   Arrheniuslaboratoriet Hus A  Plan 6  A652 i övrigt  ...   0   0
# ..                          ...     ...            ...  ...  ..  ..
# 94  Arrheniuslaboratoriet Hus A  Plan 6  A626 i övrigt  ...   0   0
# 95  Arrheniuslaboratoriet Hus A  Plan 2           A259  ...   0   0
# 96  Arrheniuslaboratoriet Hus A  Plan 2           A259  ...   4   0
# 97  Arrheniuslaboratoriet Hus A  Plan 6  A626 i övrigt  ...   1   2
# 98  Arrheniuslaboratoriet Hus A  Plan 6  A626 i övrigt  ...   1   0
#
#    pubchem_cid gcms_spectra_available lcms_spectra_available  \
# 0       7219.0                   True                  False
# 1      10724.0                   True                  False
# 2       7693.0                   True                  False
# 3      10757.0                   True                  False
# 4      11502.0                   True                  False
# ..         ...                    ...                    ...
# 94      6025.0                   True                  False
# 95     13089.0                   True                  False
# 96     33133.0                  False                  False
# 97      7250.0                   True                   True
# 98      7673.0                   True                  False
#
#                           boiling_point_peer_reviewed  \
# 0                                [181.6 °C 760 MM HG]
# 1                            [255-257 °C @ 760 MM HG]
# 2                    [204 °C, BP: 116 °C at 45 mm Hg]
# 3     [441 to 442 °F at 760 mmHg (NTP, 1992), 247 °C]
# 4                                                  []
# ..                                                ...
# 94                                                 []
# 95                                                 []
# 96                               [290 °C at 10 mm Hg]
# 97  [417 °F at 760 mmHg (NTP, 1992), 214 °C @ 760 ...
# 98                                                 []
#
#                                         boiling_point  \
# 0   [359 °F at 760 mmHg (NIOSH, 2024), 359 °F, 359...
# 1                                                  []
# 2                                                  []
# 3                        [244-245 °C, 472 °F, 472 °F]
# 4                                                  []
# ..                                                ...
# 94                                                 []
# 95                                                 []
# 96                                                 []
# 97                                           [214 °C]
# 98                                                 []
#
#                                        vapor_pressure  \
# 0                                [1.1 mm Hg at 25 °C]
# 1                                [0.02 MM HG @ 20 °C]
# 2   [VP: 95.4 mm Hg at 20 °C, 19.4 mm Hg at 25 °C ...
# 3   [0.0054 mmHg at 68 °F (NTP, 1992), Vapor press...
# 4                                                  []
# ..                                                ...
# 94                                                 []
# 95                                                 []
# 96                                                 []
# 97  [1 mmHg at 126.7 °F ; 5 mmHg at 175.6 °F; 760 ...
# 98                                                 []
#
#                                            solubility mixnr
# 0   [Insoluble (NIOSH, 2024), INSOL IN WATER, MISC...     1
# 1                                    [INSOL IN WATER]     1
# 2                       [Soluble in organic solvents]     1
# 3   [less than 1 mg/mL at 66 °F (NTP, 1992), Pract...     1
# 4                                                  []     1
# ..                                                ...   ...
# 94                                                 []    10
# 95                                                 []    10
# 96                               [Sol in acetic acid]    10
# 97  [1 to 5 mg/mL at 63 °F (NTP, 1992), Sol in alc...    11
# 98                                                 []    11
#
# [99 rows x 37 columns]

# %%
unifi_library_combined = actives[['name', 'molecular_formula', 'monoisotopic_molecular_weight', 'ROMol']].copy()

# %%
#Making all of the necessary columns for the unifi library
unifi_library_combined = unifi_library_combined.rename(columns={'name':'Item Name',
                                                                'molecular_formula':'Formula',
                                                                'monoisotopic_molecular_weight':'F1'})

unifi_library_combined['Comment'] = unifi_library_combined['Item Name']
unifi_library_combined['Description'] = np.nan #not needed
unifi_library_combined['Adduct'] = np.nan #will be added in the software
unifi_library_combined['Fragmentation'] = 'CID'
unifi_library_combined['F2'] = np.nan #not needed
unifi_library_combined['F3'] = np.nan #not needed
unifi_library_combined['RT'] = np.nan #not needed
unifi_library_combined['Structure'] = np.nan #updated in next step

# %%
#Export the mol objects for .mol files and add the file name to the dataframe

import rdkit
from rdkit import Chem
from rdkit.Chem import rdDepictor

def export_smiles(mol, name):
    """
    Function to export the RDKit molecule object to a .mol file and return the file name.
    """

    #clean name for file name
    def clean_name(name):
        '''
        Cleans name by removing unwamted formatting and characters for use as a file name
        '''
        name = name.replace(' (mass)', '').replace(' (massa)', '').replace(' (volume)', '').replace(' (Sigma-Aldrich 808314)', '').replace(' (Sigma-Aldrich 800458)', '').replace( "'", '').replace('<br>', '')
        name = name.replace(' ', '_')
        name = name.replace(',', '-').replace(':','-').replace('[', '-').replace(']','-')
        name = name.lower()

        return name

    name = clean_name(name)

    #Add hydrogens to the molecule and compute 2D coordinates
    mol = Chem.AddHs(mol)
    Chem.rdDepictor.Compute2DCoords(mol)

    #Export the molecule to a .mol file
    Chem.MolToMolFile(mol, f'{name}.mol')
    
    print(f'Exported {name}')

    return f'{name}.mol'

# %%
#Iterate over the dataframe and export the molecules to .mol files and add the file names to the dataframe

for index in unifi_library_combined.index:
    #Get the molecule from the RDKit object
    mol = unifi_library_combined.loc[index, 'ROMol']

    #Export the molecule to a .mol file
    mol_file = export_smiles(mol, unifi_library_combined.loc[index, 'Item Name'])

    #Add the file name to the dataframe
    unifi_library_combined.loc[index, 'Structure'] = mol_file

    print(f'Added {mol_file} to the dataframe \n {index+1} of {len(unifi_library_combined)}')
# Out:
# Exported indene
# Added indene.mol to the dataframe
#  1 of 99
# Exported alpha-tetralone
# Added alpha-tetralone.mol to the dataframe
#  2 of 99
# Exported 4-chlorophenyl_isocyanate
# Added 4-chlorophenyl_isocyanate.mol to the dataframe
#  3 of 99
# Exported 2-chloroacetophenone
# Added 2-chloroacetophenone.mol to the dataframe
#  4 of 99
# Exported cis-stilbene
# Added cis-stilbene.mol to the dataframe
#  5 of 99
# Exported triphenylborane
# Added triphenylborane.mol to the dataframe
#  6 of 99
# Exported p-chloranil
# Added p-chloranil.mol to the dataframe
#  7 of 99
# Exported thiourea
# Added thiourea.mol to the dataframe
#  8 of 99
# Exported 1-3-phenylenediamine
# Added 1-3-phenylenediamine.mol to the dataframe
#  9 of 99
# Exported 2-3-diaminotoluene
# Added 2-3-diaminotoluene.mol to the dataframe
#  10 of 99
# Exported n-n-dimethyl-p-toluidine
# Added n-n-dimethyl-p-toluidine.mol to the dataframe
#  11 of 99
# Exported benzhydrazide
# Added benzhydrazide.mol to the dataframe
#  12 of 99
# Exported n-n-dimethyl-p-phenylenediamine
# Added n-n-dimethyl-p-phenylenediamine.mol to the dataframe
#  13 of 99
# Exported 3-(dimethylamino)-phenol
# Added 3-(dimethylamino)-phenol.mol to the dataframe
#  14 of 99
# Exported 1-naphthol
# Added 1-naphthol.mol to the dataframe
#  15 of 99
# Exported 2-nitrophenylacetonitrile
# Added 2-nitrophenylacetonitrile.mol to the dataframe
#  16 of 99
# Exported n-n-diethyl-1-4-phenylenediammonium_sulfate
# Added n-n-diethyl-1-4-phenylenediammonium_sulfate.mol to the dataframe
#  17 of 99
# Exported n-phenyl-o-phenylenediamine
# Added n-phenyl-o-phenylenediamine.mol to the dataframe
#  18 of 99
# Exported 2-4-6-trichlorophenol
# Added 2-4-6-trichlorophenol.mol to the dataframe
#  19 of 99
# Exported myristyltrimethylammonium_bromide
# Added myristyltrimethylammonium_bromide.mol to the dataframe
#  20 of 99
# Exported 4-chloro-m-phenylenediamine
# Added 4-chloro-m-phenylenediamine.mol to the dataframe
#  21 of 99
# Exported 1-nitronaphthalene
# Added 1-nitronaphthalene.mol to the dataframe
#  22 of 99
# Exported 6-nitroquinoline
# Added 6-nitroquinoline.mol to the dataframe
#  23 of 99
# Exported 5-nitroacenaphthene
# Added 5-nitroacenaphthene.mol to the dataframe
#  24 of 99
# Exported 2-nitrofluorene
# Added 2-nitrofluorene.mol to the dataframe
#  25 of 99
# Exported n-tert-butyl-2-benzothiazolesulfenamide
# Added n-tert-butyl-2-benzothiazolesulfenamide.mol to the dataframe
#  26 of 99
# Exported tetramethylthiuram_disulfide
# Added tetramethylthiuram_disulfide.mol to the dataframe
#  27 of 99
# Exported parathion-methyl
# Added parathion-methyl.mol to the dataframe
#  28 of 99
# Exported n-cyclohexylbenzothiazole-2-sulphenamide
# Added n-cyclohexylbenzothiazole-2-sulphenamide.mol to the dataframe
#  29 of 99
# Exported quinoline_yellow
# Added quinoline_yellow.mol to the dataframe
#  30 of 99
# Exported 2-amino-4-methylphenol
# Added 2-amino-4-methylphenol.mol to the dataframe
#  31 of 99
# Exported 8-nitroquinoline
# Added 8-nitroquinoline.mol to the dataframe
#  32 of 99
# Exported anthrone
# Added anthrone.mol to the dataframe
#  33 of 99
# Exported 9-anthracenemethanol
# Added 9-anthracenemethanol.mol to the dataframe
#  34 of 99
# Exported 1-methylpyrene
# Added 1-methylpyrene.mol to the dataframe
#  35 of 99
# Exported 3-aminofluoranthene
# Added 3-aminofluoranthene.mol to the dataframe
#  36 of 99
# Exported 9-10-dihydrobenzo-a-pyrene-7(8h)-one
# Added 9-10-dihydrobenzo-a-pyrene-7(8h)-one.mol to the dataframe
#  37 of 99
# Exported 1-2-3-4-dibenzanthracene
# Added 1-2-3-4-dibenzanthracene.mol to the dataframe
#  38 of 99
# Exported p-anisidine
# Added p-anisidine.mol to the dataframe
#  39 of 99
# Exported n-n-dimethyl-4-nitrosoaniline
# Added n-n-dimethyl-4-nitrosoaniline.mol to the dataframe
#  40 of 99
# Exported 4-4-dihydroxybiphenyl
# Added 4-4-dihydroxybiphenyl.mol to the dataframe
#  41 of 99
# Exported 2-methylanthraquinone
# Added 2-methylanthraquinone.mol to the dataframe
#  42 of 99
# Exported 1-(2-chlorophenyl)-1-(4-chlorophenyl)-2-2-dichloroethane
# Added 1-(2-chlorophenyl)-1-(4-chlorophenyl)-2-2-dichloroethane.mol to the dataframe
#  43 of 99
# Exported 3-pyridinecarbonitrile
# Added 3-pyridinecarbonitrile.mol to the dataframe
#  44 of 99
# Exported m-toluidine
# Added m-toluidine.mol to the dataframe
#  45 of 99
# Exported n-phenylhydroxylamine
# Added n-phenylhydroxylamine.mol to the dataframe
#  46 of 99
# Exported 2-6-diaminopyridine
# Added 2-6-diaminopyridine.mol to the dataframe
#  47 of 99
# Exported 4-methyl-1-2-phenylendiamine
# Added 4-methyl-1-2-phenylendiamine.mol to the dataframe
#  48 of 99
# Exported 2-methoxy-5-methylaniline
# Added 2-methoxy-5-methylaniline.mol to the dataframe
#  49 of 99
# Exported 2-aminobenzothiazole
# Added 2-aminobenzothiazole.mol to the dataframe
#  50 of 99
# Exported 2-nitro-1-phenylpropene
# Added 2-nitro-1-phenylpropene.mol to the dataframe
#  51 of 99
# Exported 3-diethylaminophenol
# Added 3-diethylaminophenol.mol to the dataframe
#  52 of 99
# Exported 1-fluoro-2-4-dinitrobenzene
# Added 1-fluoro-2-4-dinitrobenzene.mol to the dataframe
#  53 of 99
# Exported 2-4-diamino-6-fenyl-s-triazin
# Added 2-4-diamino-6-fenyl-s-triazin.mol to the dataframe
#  54 of 99
# Exported 2-4-5-trichlorophenol
# Added 2-4-5-trichlorophenol.mol to the dataframe
#  55 of 99
# Exported 9-anthracenecarbonitrile
# Added 9-anthracenecarbonitrile.mol to the dataframe
#  56 of 99
# Exported perthan
# Added perthan.mol to the dataframe
#  57 of 99
# Exported 4-butylphenol
# Added 4-butylphenol.mol to the dataframe
#  58 of 99
# Exported 2-5-diklorfenol
# Added 2-5-diklorfenol.mol to the dataframe
#  59 of 99
# Exported 2-3-6-triklorfenol
# Added 2-3-6-triklorfenol.mol to the dataframe
#  60 of 99
# Exported 4-octylphenol
# Added 4-octylphenol.mol to the dataframe
#  61 of 99
# Exported 2-acetylfluorene
# Added 2-acetylfluorene.mol to the dataframe
#  62 of 99
# Exported cedrol
# Added cedrol.mol to the dataframe
#  63 of 99
# Exported (3-chloropropyl)triethoxysilane
# Added (3-chloropropyl)triethoxysilane.mol to the dataframe
#  64 of 99
# Exported 2-2-5-2-terthiophene
# Added 2-2-5-2-terthiophene.mol to the dataframe
#  65 of 99
# Exported tetrasul
# Added tetrasul.mol to the dataframe
#  66 of 99
# Exported bis(4-bromophenyl)_ether
# Added bis(4-bromophenyl)_ether.mol to the dataframe
#  67 of 99
# Exported 2-4-bis(a-a-dimetylbensyl)fenol
# Added 2-4-bis(a-a-dimetylbensyl)fenol.mol to the dataframe
#  68 of 99
# Exported allyl_2-4-6-tribromophenyl_ether
# Added allyl_2-4-6-tribromophenyl_ether.mol to the dataframe
#  69 of 99
# Exported trans-chlordane
# Added trans-chlordane.mol to the dataframe
#  70 of 99
# Exported diaminomaleonitrile
# Added diaminomaleonitrile.mol to the dataframe
#  71 of 99
# Exported phenylhydrazine
# Added phenylhydrazine.mol to the dataframe
#  72 of 99
# Exported 1-3-4-thiadiazole-2-5-dithiol
# Added 1-3-4-thiadiazole-2-5-dithiol.mol to the dataframe
#  73 of 99
# Exported 2-ethylanthraquinone
# Added 2-ethylanthraquinone.mol to the dataframe
#  74 of 99
# Exported 4-4-ddd
# Added 4-4-ddd.mol to the dataframe
#  75 of 99
# Exported cresyl_diphenyl_phosphate
# Added cresyl_diphenyl_phosphate.mol to the dataframe
#  76 of 99
# Exported metoxiklor
# Added metoxiklor.mol to the dataframe
#  77 of 99
# Exported heptaklor
# Added heptaklor.mol to the dataframe
#  78 of 99
# Exported heptaklorepoxid
# Added heptaklorepoxid.mol to the dataframe
#  79 of 99
# Exported bromophos-ethyl
# Added bromophos-ethyl.mol to the dataframe
#  80 of 99
# Exported alpha-chlordane
# Added alpha-chlordane.mol to the dataframe
#  81 of 99
# Exported 3-4-dimethylaniline
# Added 3-4-dimethylaniline.mol to the dataframe
#  82 of 99
# Exported 2-3-5-trimethylphenol
# Added 2-3-5-trimethylphenol.mol to the dataframe
#  83 of 99
# Exported 4-ethoxyaniline
# Added 4-ethoxyaniline.mol to the dataframe
#  84 of 99
# Exported 4-nitro-1-2-phynelenediamine
# Added 4-nitro-1-2-phynelenediamine.mol to the dataframe
#  85 of 99
# Exported 2-tert-butyl-5-methylphenol
# Added 2-tert-butyl-5-methylphenol.mol to the dataframe
#  86 of 99
# Exported 2-tert-butyl-4-ethylphenol
# Added 2-tert-butyl-4-ethylphenol.mol to the dataframe
#  87 of 99
# Exported 4-benzylphenol
# Added 4-benzylphenol.mol to the dataframe
#  88 of 99
# Exported 4-methyl-2-6-dinitrophenol
# Added 4-methyl-2-6-dinitrophenol.mol to the dataframe
#  89 of 99
# Exported m-terphenyl
# Added m-terphenyl.mol to the dataframe
#  90 of 99
# Exported 4-chloro-3-methylphenol
# Added 4-chloro-3-methylphenol.mol to the dataframe
#  91 of 99
# Exported 3-5-dichlorophenol
# Added 3-5-dichlorophenol.mol to the dataframe
#  92 of 99
# Exported 2-3-4-trichlorophenol
# Added 2-3-4-trichlorophenol.mol to the dataframe
#  93 of 99
# Exported iso_e_super
# Added iso_e_super.mol to the dataframe
#  94 of 99
# Exported triphenylethylene
# Added triphenylethylene.mol to the dataframe
#  95 of 99
# Exported o-p-ddt
# Added o-p-ddt.mol to the dataframe
#  96 of 99
# Exported tris(dimethylphenyl)-phosphate
# Added tris(dimethylphenyl)-phosphate.mol to the dataframe
#  97 of 99
# Exported 2-4-dimethylaniline
# Added 2-4-dimethylaniline.mol to the dataframe
#  98 of 99
# Exported phenyl_isothiocyanate
# Added phenyl_isothiocyanate.mol to the dataframe
#  99 of 99
# /var/folders/0w/cl6vcbp52mjfxw4v9_2l1_780000gn/T/ipykernel_3561/3314626763.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'indene.mol' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   unifi_library_combined.loc[index, 'Structure'] = mol_file

# %%
#Reorder the columns to match the Unifi library format
unifi_library_combined_reformated = unifi_library_combined[['Item Name', 'Formula', 'Comment', 'Description', 'Adduct', 'Fragmentation', 'F1', 'F2', 'F3', 'RT', 'Structure']]

unifi_library_combined_reformated.head()
# Out:
#                    Item Name   Formula                    Comment  \
# 0              Indene (mass)      C9H8              Indene (mass)
# 1   alpha-Tetralone (volume)   C10H10O   alpha-Tetralone (volume)
# 2  4-Chlorophenyl isocyanate  C7H4ClNO  4-Chlorophenyl isocyanate
# 3       2-Chloroacetophenone   C8H7ClO       2-Chloroacetophenone
# 4        cis-Stilbene (mass)    C14H12        cis-Stilbene (mass)
#
#    Description  Adduct Fragmentation          F1  F2  F3  RT  \
# 0          NaN     NaN           CID    116.0626 NaN NaN NaN
# 1          NaN     NaN           CID  146.073165 NaN NaN NaN
# 2          NaN     NaN           CID  152.998141 NaN NaN NaN
# 3          NaN     NaN           CID  154.018543 NaN NaN NaN
# 4          NaN     NaN           CID    180.0939 NaN NaN NaN
#
#                        Structure
# 0                     indene.mol
# 1            alpha-tetralone.mol
# 2  4-chlorophenyl_isocyanate.mol
# 3       2-chloroacetophenone.mol
# 4               cis-stilbene.mol

# %%
#Get the names of the actives with halogens and non-halogens
actives_halogenated_names = actives[(actives.Chlorines > 2)|(actives.Bromines > 1)]['name'].tolist() #25 halogenated compounds
actives_nonhalogens_names = actives[(actives.Chlorines == 0)&(actives.Bromines == 0)]['name'].tolist() #74 non-halogenated compounds

#Create a library with the halogenated and non-halogenated compounds
halogenated_library = unifi_library_combined_reformated[unifi_library_combined_reformated['Item Name'].isin(actives_halogenated_names)].copy() #25 halogenated compounds
nonhalogenated_library = unifi_library_combined_reformated[unifi_library_combined_reformated['Item Name'].isin(actives_nonhalogens_names)].copy() #74 non-halogenated compounds

# %%
#Export to excel files
halogenated_library.to_excel('2025-04-29_UNIFI_library_above_2Cl_1Br.xlsx', index=False)
nonhalogenated_library.to_excel('2025-04-29_UNIFI_library_below_3Cl_2Br.xlsx', index=False)
