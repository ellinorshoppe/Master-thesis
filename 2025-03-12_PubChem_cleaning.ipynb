# %% [markdown]
# # Cleaning PubChemLite (Feb 2025)

# %%
import pandas as pd
import numpy as np

import rdkit
from rdkit import Chem, rdBase, RDLogger, DataStructs
RDLogger.DisableLog('rdApp.*')
from rdkit.Chem import AllChem, Draw, inchi, rdDepictor, PandasTools, SaltRemover, Descriptors
from rdkit.Chem.Draw import IPythonConsole, rdMolDraw2D
from rdkit.Chem.MolStandardize import rdMolStandardize

import pickle

# %%
pubchemlite_orig = pd.read_csv('PubChemLite_CCSbase_20250228.csv')

pubchemlite = pubchemlite_orig[['SMILES', 'InChIKey', 'CompoundName', 'Identifier', 'XLogP', 'MonoisotopicMass']]
pubchemlite.rename(columns={'Identifier': 'pubchem_cid',
                                   'CompoundName':'name',
                                   'MonoisotopicMass':'monoisotopic_mass_pubchem',
                                   'InChIKey':'InChIKey_pubchem',
                                   'SMILES':'SMILES_pubchem',
                                   'XLogP':'XLogP_pubchem'}, inplace=True)
pubchemlite
# Out:
# /var/folders/0w/cl6vcbp52mjfxw4v9_2l1_780000gn/T/ipykernel_76559/3596150552.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pubchemlite.rename(columns={'Identifier': 'pubchem_cid',
#                                            SMILES_pubchem  \
# 0                                C1=CC(C(C(=C1)C(=O)O)O)O
# 1                                                 CC(CN)O
# 2                                    C(C(=O)COP(=O)(O)O)N
# 3               C1=CC(=C(C=C1[N+](=O)[O-])[N+](=O)[O-])Cl
# 4                                     CCC(C)(C(C(=O)O)O)O
# ...                                                   ...
# 408805  C1=CC(=C(C=C1NC(=O)NC2=C(C=C(C=C2)Cl)C3=C(C=CC...
# 408806          B1(OC(C(O1)(C)C)(C)C)C2=CC(=CN=C2)OC3COC3
# 408807      B1(OC(C(O1)(C)C)(C)C)C2=C(C=C(C=C2)C3COC3)C#N
# 408808      B1(OC(C(O1)(C)C)(C)C)C2=C(C=CC(=C2)C3COC3)C#N
# 408809                                   C1CC12CC(=O)COC2
#
#                    InChIKey_pubchem  \
# 0       INCSWYKICIYAHB-UHFFFAOYSA-N
# 1       HXKKHQJGJAFBHI-UHFFFAOYSA-N
# 2       HIQNVODXENYOFK-UHFFFAOYSA-N
# 3       VYZAHLCBVHPDDF-UHFFFAOYSA-N
# 4       PDGXJDXVGMHUIR-UHFFFAOYSA-N
# ...                             ...
# 408805  CAWJHCNZWVFAPL-UHFFFAOYSA-N
# 408806  VLOPGBXDLHSTBE-UHFFFAOYSA-N
# 408807  YMEYBJPAQUDGPW-UHFFFAOYSA-N
# 408808  IYBNKVGFHAWEDF-UHFFFAOYSA-N
# 408809  JJGIPGOUJRWUGW-UHFFFAOYSA-N
#
#                                                      name  pubchem_cid  \
# 0       5,6-dihydroxycyclohexa-1,3-diene-1-carboxylic ...            3
# 1                                      1-aminopropan-2-ol            4
# 2              (3-amino-2-oxopropyl) dihydrogen phosphate            5
# 3                             1-chloro-2,4-dinitrobenzene            6
# 4                    2,3-dihydroxy-3-methylpentanoic acid            8
# ...                                                   ...          ...
# 408805  1-[4-chloro-2-[6-chloro-3-(2,4-dichlorophenoxy...    172643734
# 408806  3-(oxetan-3-yloxy)-5-(4,4,5,5-tetramethyl-1,3,...    172644635
# 408807  5-(oxetan-3-yl)-2-(4,4,5,5-tetramethyl-1,3,2-d...    172645001
# 408808  4-(oxetan-3-yl)-2-(4,4,5,5-tetramethyl-1,3,2-d...    172645595
# 408809                         5-oxaspiro[2.5]octan-7-one    172653597
#
#         XLogP_pubchem  monoisotopic_mass_pubchem
# 0                -0.3                 156.042259
# 1                -1.0                  75.068414
# 2                -5.0                 169.014009
# 3                 2.3                 201.978134
# 4                -0.4                 148.073559
# ...               ...                        ...
# 408805            9.1                 599.913558
# 408806            NaN                 277.148538
# 408807            NaN                 285.153624
# 408808            NaN                 285.153624
# 408809            0.2                 126.068080
#
# [408810 rows x 6 columns]

# %% [markdown]
# ### Cleaning of the SMILES and convertion to ROMol objects
# The InChIKey, new SMILES and InChIKey14 will be computed from the ROMol objects after desalting and uncharging has been done.

# %%
PandasTools.AddMoleculeColumnToFrame(pubchemlite, smilesCol='SMILES_pubchem', molCol='ROMol')

pubchemlite.ROMol.isna().sum()
# Out:
# /opt/anaconda3/envs/MS2Tox_APGC/lib/python3.12/site-packages/rdkit/Chem/PandasTools.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(Chem.MolFromSmiles)
# np.int64(9)

# %%
pubchemlite[pubchemlite.ROMol.isna()==True]
# Out:
#                                            SMILES_pubchem  \
# 13982                                       O=Cl(=O)(=O)F
# 14115                                             FBr(F)F
# 14117                                       FBr(F)(F)(F)F
# 14137                                             FCl(F)F
# 32298                                       FCl(F)(F)(F)F
# 46001                                  FI(F)(F)(F)(F)(F)F
# 162802  C1=CC=C2C(=C1)O[Si-2]34(O2)(OC5=CC=CC=C5O3)OC6...
# 266999  CC1=CC(=[N+](C(=C1)C)[Br-][N+]2=C(C=C(C=C2C)C)C)C
# 277611                   C1=CC=C(C=C1)[Si](Cl)(Cl)[Cl-]Cl
#
#                    InChIKey_pubchem  \
# 13982   XHFXMNZYIKFCPN-UHFFFAOYSA-N
# 14115   FQFKTKUFHWNTBN-UHFFFAOYSA-N
# 14117   XHVUVQAANZKEKF-UHFFFAOYSA-N
# 14137   JOHWNGGYGAVMGU-UHFFFAOYSA-N
# 32298   KNSWNNXPAWSACI-UHFFFAOYSA-N
# 46001   XRURPHMPXJDCOO-UHFFFAOYSA-N
# 162802  JIICOOGKGWBPSB-UHFFFAOYSA-N
# 266999  DWDPGQBPOJKMQW-UHFFFAOYSA-N
# 277611  MIUKAZMTBNWUDP-UHFFFAOYSA-N
#
#                                                      name  pubchem_cid  \
# 13982                                 perchloryl fluoride        24258
# 14115                           trifluoro-lambda3-bromane        24594
# 14117                         pentafluoro-lambda5-bromane        24606
# 14137                          trifluoro-lambda3-chlorane        24637
# 32298                        pentafluoro-lambda5-chlorane        61654
# 46001                          heptafluoro-lambda7-iodane        85645
# 162802                                                NaN      3470663
# 266999  2,4,6-trimethyl-1-(2,4,6-trimethylpyridin-1-iu...     44629788
# 277611           dichloro-chlorochloranuidyl-phenylsilane     53400412
#
#         XLogP_pubchem  monoisotopic_mass_pubchem ROMol
# 13982             3.3                 101.952000  None
# 14115             2.6                 135.913550  None
# 14117             3.7                 173.910350  None
# 14137             2.5                  91.964062  None
# 32298             3.6                 129.960869  None
# 46001             4.7                 259.893290  None
# 162802            NaN                 352.040315  None
# 266999            5.5                 321.096640  None
# 277611            NaN                 244.891462  None

# %%
pubchemlite = pubchemlite.dropna(subset=['ROMol'])

# %%
salts = pubchemlite.SMILES_pubchem.str.contains(r'\.')

salts.sum() #Is 0 so no salt removal needed
# Out:
# np.int64(0)

# %%
def contains_carbon(mol):
    try:
        atomic_no = [atom.GetAtomicNum() for atom in mol.GetAtoms()]
        return bool(6 in atomic_no)
    except:
        return np.nan

pubchemlite['contains_carbon'] = pubchemlite.ROMol.apply(lambda x: contains_carbon(x))
pubchemlite = pubchemlite[pubchemlite.contains_carbon == True]
pubchemlite = pubchemlite.drop(columns=['contains_carbon'])
# Out:
# /var/folders/0w/cl6vcbp52mjfxw4v9_2l1_780000gn/T/ipykernel_76559/1547849159.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pubchemlite['contains_carbon'] = pubchemlite.ROMol.apply(lambda x: contains_carbon(x))

# %%
uncharger = rdMolStandardize.Uncharger()  # neutralize the molecule (if possible)
pubchemlite['ROMol'] = pubchemlite.ROMol.apply(lambda x: uncharger.uncharge(x))

# def neutralize_atoms(mol):
#     try:
#         pattern = Chem.MolFromSmarts("[+1!h0!$([*]~[-1,-2,-3,-4]),-1!$([*]~[+1,+2,+3,+4])]")
#         at_matches = mol.GetSubstructMatches(pattern)
#         at_matches_list = [y[0] for y in at_matches]
#         if len(at_matches_list) > 0:
#             for at_idx in at_matches_list:
#                 atom = mol.GetAtomWithIdx(at_idx)
#                 chg = atom.GetFormalCharge()
#                 hcount = atom.GetTotalNumHs()
#                 atom.SetFormalCharge(0)
#                 atom.SetNumExplicitHs(hcount - chg)
#                 atom.UpdatePropertyCache()
#         return mol
#     except:
#         return mol

#pubchemlite_subset['ROMol'] = pubchemlite_subset.ROMol.apply(lambda x: neutralize_atoms(x))
pubchemlite.ROMol.apply(lambda x: Chem.RemoveStereochemistry(x)) 
pubchemlite['SMILES'] = pubchemlite.ROMol.apply(lambda x: Chem.MolToSmiles(x))
pubchemlite['InChIKey'] = pubchemlite.ROMol.apply(lambda x: inchi.MolToInchiKey(x))
pubchemlite['InChIKey14'] = pubchemlite.InChIKey.apply(lambda x: x.split('-')[0])

# %%
pubchemlite_dupl = pubchemlite[pubchemlite.duplicated(subset=['InChIKey', 'SMILES'], keep=False)]
pubchemlite_dupl = pubchemlite_dupl.sort_values(by='InChIKey')
pubchemlite_dupl
# Out:
#                                            SMILES_pubchem  \
# 212955                            C1=CC=C2C(=C1)N=NN2[O-]
# 40303                                C1=CC=C2C(=C1)N=NN2O
# 72524                                 C=C1C=NC2=CC=CC=C12
# 327565                            [CH+]=C1C=NC2=CC=CC=C12
# 259091                   C1=CC=C2C(=C1)N(C(=O)C(O2)O)[O-]
# 15950                       C1=CC=C2C(=C1)N(C(=O)C(O2)O)O
# 393497                                 CC(=C[CH+]C(=O)O)C
# 35975                                      CC(=CCC(=O)O)C
# 320975  CN(C)CCCN(O)S(=O)(=O)CCC(C(C(C(C(C(F)(F)F)(F)F...
# 69861   CN(C)CCCN([O-])S(=O)(=O)CCC(C(C(C(C(C(F)(F)F)(...
# 191129  C/C(=C/C(=O)N(CCCC1C(=O)NC(C(=O)NC(C(=O)NC(C(=...
# 318649  C/C(=C/C(=O)N(CCCC1C(=O)NC(C(=O)NC(C(=O)NC(C(=...
# 258979                 COC1=CC2=C(C=C1)N(C(=O)C(O2)O)[O-]
# 830                       COC1=CC2=C(C=C1)N(C(=O)C(O2)O)O
# 37218                           C1=CC=C(C=C1)PC2=CC=CC=C2
# 95474                        C1=CC=C(C=C1)[P-]C2=CC=CC=C2
# 259068                           C1=CC=C(C=C1)CC(=S)N[O-]
# 161598                              C1=CC=C(C=C1)CC(=S)NO
# 70075                   C1=CN(C(=N1)[N+](=O)[O-])CC(=O)NO
# 156542               C1=CN(C(=N1)[N+](=O)[O-])CC(=O)N[O-]
# 44430               C1=CC2=C3C(=C1)C(=O)N(C(=O)C3=CC=C2)O
# 161424           C1=CC2=C3C(=C1)C(=O)N(C(=O)C3=CC=C2)[O-]
# 119093                                    [BH-](CC)(CC)CC
# 3380                                          B(CC)(CC)CC
# 2295                                               [C-]#N
# 288                                                   C#N
# 329327                          C1=CC(=CC=C1CC(=S)N[O-])O
# 270459                             C1=CC(=CC=C1CC(=S)NO)O
# 158134                                           CN(C=S)O
# 72193                                         CN(C=S)[O-]
# 393328                             C=C[CH+]C(=O)C(=O)[O-]
# 364                                       C=CCC(=O)C(=O)O
# 258984                   C1=CC=C2C(=C1)C(=CN2)CC(=S)N[O-]
# 258205                      C1=CC=C2C(=C1)C(=CN2)CC(=S)NO
# 226839  [BH-]1(C2CCCC1CCC2)[C@H]3C[C@H]4C[C@@H]([C@@H]...
# 218896  B1(C2CCCC1CCC2)[C@H]3C[C@H]4C[C@@H]([C@@H]3CCO...
# 38778                                CC(C)N(C(=O)C(=O)O)O
# 284575                            CC(C)N(C(=O)C(=O)O)[O-]
# 73702                             CC1=C(C=CC(=O)N1[O-])OC
# 73650                                CC1=C(C=CC(=O)N1O)OC
# 1050    CC(=O)N(CCCCCNC(=O)CCC(=O)N(CCCCCNC(=O)CCC(=O)...
# 65279   CC(=O)N(CCCCCNC(=O)CCC(=O)N(CCCCCNC(=O)CCC(=O)...
# 178210                          C1=CC=C(C=C1)/C=C/C(=O)NO
# 184470                       C1=CC=C(C=C1)/C=C/C(=O)N[O-]
# 19616                             C1=CC=C(C=C1)C(=O)N[O-]
# 5496                                 C1=CC=C(C=C1)C(=O)NO
# 158104                                    [BH-](OC)(OC)OC
# 4357                                          B(OC)(OC)OC
# 268                                                   C=O
# 184356                                            [CH+]=O
# 11480                                C1=CC(=S)N(C=C1)[O-]
# 556                                     C1=CC(=S)N(C=C1)O
# 72275   CC(=O)N(CCC[C@H]1C(=O)N[C@H](C(=O)N[C@H](C(=O)...
# 326176  CC(=O)N(CCC[C@H]1C(=O)N[C@H](C(=O)N[C@H](C(=O)...
# 35672                                      C(CCC(=O)N)CCN
# 397262                                 C(CCN)C[CH+]C(=O)N
#
#                    InChIKey_pubchem  \
# 212955  VGZMHTGJWOPMTH-UHFFFAOYSA-N
# 40303   ASOKPJOREAFHNY-UHFFFAOYSA-N
# 1050    N-[5-[[4-[5-[acetyl(hydroxy)amino]pentylamino]...         2973
# 65279   N-[5-[[4-[5-[acetyl(oxido)amino]pentylamino]-4...       123852
# 178210               (E)-N-hydroxy-3-phenylprop-2-enamide      5355635
# 184470                 (E)-N-oxido-3-phenylprop-2-enamide      6433395
# 19616                                    N-oxidobenzamide        36579
# 5496                                   N-hydroxybenzamide        10313
# 158104                                trimethoxyboranuide      3084263
# 4357                                     trimethyl borate         8470
# 268                                          formaldehyde          712
# 184356                                          methanone      6432172
# 11480                            1-oxidopyridine-2-thione        19659
# 556                            1-hydroxypyridine-2-thione         1570
# 72275   N-[3-[(2S,5S,8S)-5,8-bis[3-[acetyl(hydroxy)ami...       169636
# 326176  N-[3-[(2S,5S,8S)-5,8-bis[3-[acetyl(oxido)amino...    121489512
# 35672                                   6-aminohexanamide        67798
# 397262                                  6-aminohexanamide    138399349
#
#         XLogP_pubchem  monoisotopic_mass_pubchem  \
# 212955            0.7                 134.035437
# 40303             1.2                 135.043262
# 72524             1.7                 129.057849
# 327565            1.7                 128.050024
# 259091           -0.1                 180.029683
# 15950             0.0                 181.037508
# 393497            1.4                 113.060255
# 35975             1.4                 114.068080
# 320975            4.2                 528.075230
# 69861             4.2                 527.067405
# 191129           -3.5                 996.379810
# 318649           -3.2                 999.403285
# 258979           -0.1                 210.040247
# 830               0.0                 211.048072
# 37218             3.0                 186.059837
# 95474             3.0                 185.052012
# 259068            1.2                 166.032660
# 161598            1.2                 167.040485
# 70075            -1.1                 186.038905
# 156542           -1.2                 185.031080
# 44430             1.7                 213.042593
# 161424            1.6                 212.034768
# 119093            NaN                  99.134506
# 3380              NaN                  98.126681
# 2295              0.1                  26.003074
# 288               0.1                  27.010899
# 329327            0.8                 182.027575
# 270459            0.9                 183.035400
# 158134           -0.2                  91.009185
# 72193            -0.2                  90.001360
# 393328            1.1                 112.016044
# 364               0.4                 114.031694
# 258984            1.2                 205.043559
# 258205            1.3                 206.051384
# 226839            NaN                 379.317221
# 218896            NaN                 378.309396
# 38778             0.5                 147.053158
# 284575            0.5                 146.045333
# 73702            -0.1                 154.050418
# 73650             0.0                 155.058243
# 1050             -2.1                 560.353363
# 65279            -2.4                 557.329887
# 178210            1.4                 163.063329
# 184470            1.3                 162.055503
# 19616             0.3                 136.039853
# 5496              0.3                 137.047678
# 158104            NaN                 105.072299
# 4357              NaN                 104.064474
# 268               1.2                  30.010565
# 184356            1.2                  29.002740
# 11480             0.4                 126.001360
# 556               0.5                 127.009185
# 72275            -4.7                 687.318768
# 326176           -4.9                 684.295293
# 35672            -1.3                 130.110613
# 397262           -1.3                 129.102788
#
#                                                 ROMol  \
# 212955  <rdkit.Chem.rdchem.Mol object at 0x1739d5770>
# 40303   <rdkit.Chem.rdchem.Mol object at 0x1693cf450>
# 72524   <rdkit.Chem.rdchem.Mol object at 0x14e988eb0>
# 327565  <rdkit.Chem.rdchem.Mol object at 0x176c96500>
# 259091  <rdkit.Chem.rdchem.Mol object at 0x14d15a0a0>
# 15950   <rdkit.Chem.rdchem.Mol object at 0x14d8959a0>
# 393497  <rdkit.Chem.rdchem.Mol object at 0x1499d4f90>
# 35975   <rdkit.Chem.rdchem.Mol object at 0x300f18200>
# 320975  <rdkit.Chem.rdchem.Mol object at 0x13e478890>
# 69861   <rdkit.Chem.rdchem.Mol object at 0x14e9d4040>
# 191129  <rdkit.Chem.rdchem.Mol object at 0x14de33450>
# 318649  <rdkit.Chem.rdchem.Mol object at 0x13e4c46d0>
# 258979  <rdkit.Chem.rdchem.Mol object at 0x14d15ef10>
# 830     <rdkit.Chem.rdchem.Mol object at 0x1763025e0>
# 37218   <rdkit.Chem.rdchem.Mol object at 0x1693965e0>
# 95474   <rdkit.Chem.rdchem.Mol object at 0x1690bd9a0>
# 259068  <rdkit.Chem.rdchem.Mol object at 0x14d159690>
# 161598  <rdkit.Chem.rdchem.Mol object at 0x14a3acd60>
# 70075   <rdkit.Chem.rdchem.Mol object at 0x14e9c2260>
# 156542  <rdkit.Chem.rdchem.Mol object at 0x168169930>
# 44430   <rdkit.Chem.rdchem.Mol object at 0x1693087b0>
# 161424  <rdkit.Chem.rdchem.Mol object at 0x14a3bbed0>
# 119093  <rdkit.Chem.rdchem.Mol object at 0x1697e4b30>
# 3380    <rdkit.Chem.rdchem.Mol object at 0x176288820>
# 2295    <rdkit.Chem.rdchem.Mol object at 0x1762aaa40>
# 288     <rdkit.Chem.rdchem.Mol object at 0x1762c83c0>
# 329327  <rdkit.Chem.rdchem.Mol object at 0x176c710e0>
# 270459  <rdkit.Chem.rdchem.Mol object at 0x14fd33840>
# 158134  <rdkit.Chem.rdchem.Mol object at 0x1681415b0>
# 72193   <rdkit.Chem.rdchem.Mol object at 0x14e993ca0>
# 393328  <rdkit.Chem.rdchem.Mol object at 0x149990510>
# 364     <rdkit.Chem.rdchem.Mol object at 0x1762c9e00>
# 258984  <rdkit.Chem.rdchem.Mol object at 0x14d15f140>
# 258205  <rdkit.Chem.rdchem.Mol object at 0x14d171a10>
# 226839  <rdkit.Chem.rdchem.Mol object at 0x16a80d690>
# 218896  <rdkit.Chem.rdchem.Mol object at 0x16a8da570>
# 38778   <rdkit.Chem.rdchem.Mol object at 0x1693b1540>
# 284575  <rdkit.Chem.rdchem.Mol object at 0x17658ce40>
# 73702   <rdkit.Chem.rdchem.Mol object at 0x14e965690>
# 73650   <rdkit.Chem.rdchem.Mol object at 0x14e973f40>
# 1050    <rdkit.Chem.rdchem.Mol object at 0x1762c4740>
# 65279   <rdkit.Chem.rdchem.Mol object at 0x168c62420>
# 178210  <rdkit.Chem.rdchem.Mol object at 0x14aac6730>
# 184470  <rdkit.Chem.rdchem.Mol object at 0x14aa11070>
# 19616   <rdkit.Chem.rdchem.Mol object at 0x14d84e5e0>
# 5496    <rdkit.Chem.rdchem.Mol object at 0x16b76ec70>
# 158104  <rdkit.Chem.rdchem.Mol object at 0x168140890>
# 4357    <rdkit.Chem.rdchem.Mol object at 0x17627b680>
# 268     <rdkit.Chem.rdchem.Mol object at 0x173beba70>
# 184356  <rdkit.Chem.rdchem.Mol object at 0x14aa1de00>
# 11480   <rdkit.Chem.rdchem.Mol object at 0x16b716960>
# 556     <rdkit.Chem.rdchem.Mol object at 0x1762fedc0>
# 72275   <rdkit.Chem.rdchem.Mol object at 0x14e9960a0>
# 326176  <rdkit.Chem.rdchem.Mol object at 0x176cdc040>
# 35672   <rdkit.Chem.rdchem.Mol object at 0x300f27bc0>
# 397262  <rdkit.Chem.rdchem.Mol object at 0x149970cf0>
#
#                                                    SMILES  \
# 212955                                     On1nnc2ccccc21
# 40303                                      On1nnc2ccccc21
# 72524                                    C=C1C=Nc2ccccc21
# 327565                                   C=C1C=Nc2ccccc21
# 259091                               O=C1C(O)Oc2ccccc2N1O
# 15950                                O=C1C(O)Oc2ccccc2N1O
# 393497                                     CC(C)=CCC(=O)O
# 35975                                      CC(C)=CCC(=O)O
# 320975  CN(C)CCCN(O)S(=O)(=O)CCC(F)(F)C(F)(F)C(F)(F)C(...
# 69861   CN(C)CCCN(O)S(=O)(=O)CCC(F)(F)C(F)(F)C(F)(F)C(...
# 191129  CC(=CC(=O)N(O)CCCC1NC(=O)CNC(=O)C(CO)NC(=O)C(C...
# 318649  CC(=CC(=O)N(O)CCCC1NC(=O)CNC(=O)C(CO)NC(=O)C(C...
# 258979                         COc1ccc2c(c1)OC(O)C(=O)N2O
# 830                            COc1ccc2c(c1)OC(O)C(=O)N2O
# 37218                                 c1ccc(Pc2ccccc2)cc1
# 95474                                 c1ccc(Pc2ccccc2)cc1
# 259068                                   ONC(=S)Cc1ccccc1
# 161598                                   ONC(=S)Cc1ccccc1
# 70075                         O=C(Cn1ccnc1[N+](=O)[O-])NO
# 156542                        O=C(Cn1ccnc1[N+](=O)[O-])NO
# 44430                        O=C1c2cccc3cccc(c23)C(=O)N1O
# 161424                       O=C1c2cccc3cccc(c23)C(=O)N1O
# 119093                                          CCB(CC)CC
# 3380                                            CCB(CC)CC
# 2295                                                  C#N
# 288                                                   C#N
# 329327                                ONC(=S)Cc1ccc(O)cc1
# 270459                                ONC(=S)Cc1ccc(O)cc1
# 158134                                           CN(O)C=S
# 72193                                            CN(O)C=S
# 393328                                    C=CCC(=O)C(=O)O
# 364                                       C=CCC(=O)C(=O)O
# 258984                           ONC(=S)Cc1c[nH]c2ccccc12
# 258205                           ONC(=S)Cc1c[nH]c2ccccc12
# 226839       CC1(C)C2CC(B3C4CCCC3CCC4)C(CCOCc3ccccc3)C1C2
# 218896       CC1(C)C2CC(B3C4CCCC3CCC4)C(CCOCc3ccccc3)C1C2
# 38778                                CC(C)N(O)C(=O)C(=O)O
# 284575                               CC(C)N(O)C(=O)C(=O)O
# 73702                                  COc1ccc(=O)n(O)c1C
# 73650                                  COc1ccc(=O)n(O)c1C
# 1050    CC(=O)N(O)CCCCCNC(=O)CCC(=O)N(O)CCCCCNC(=O)CCC...
# 65279   CC(=O)N(O)CCCCCNC(=O)CCC(=O)N(O)CCCCCNC(=O)CCC...
# 178210                                 O=C(C=Cc1ccccc1)NO
# 184470                                 O=C(C=Cc1ccccc1)NO
# 19616                                     O=C(NO)c1ccccc1
# 5496                                      O=C(NO)c1ccccc1
pubchemlite_dupl_removed = pubchemlite_dupl[~(pubchemlite_dupl.monoisotopic_mass_diff > 1)] #Removes the duplicates with a mass difference of more than 1 Da
pubchemlite_dupl_removed = pubchemlite_dupl_removed.drop(columns=['monoisotopic_mass_new', 'monoisotopic_mass_diff']) #drops the columns concerning the mass difference
pubchemlite_dupl_removed
# Out:
#                                            SMILES_pubchem  \
# 40303                                C1=CC=C2C(=C1)N=NN2O
# 72524                                 C=C1C=NC2=CC=CC=C12
# 15950                       C1=CC=C2C(=C1)N(C(=O)C(O2)O)O
# 35975                                      CC(=CCC(=O)O)C
# 320975  CN(C)CCCN(O)S(=O)(=O)CCC(C(C(C(C(C(F)(F)F)(F)F...
# 318649  C/C(=C/C(=O)N(CCCC1C(=O)NC(C(=O)NC(C(=O)NC(C(=...
# 830                       COC1=CC2=C(C=C1)N(C(=O)C(O2)O)O
# 37218                           C1=CC=C(C=C1)PC2=CC=CC=C2
# 161598                              C1=CC=C(C=C1)CC(=S)NO
# 70075                   C1=CN(C(=N1)[N+](=O)[O-])CC(=O)NO
# 44430               C1=CC2=C3C(=C1)C(=O)N(C(=O)C3=CC=C2)O
# 3380                                          B(CC)(CC)CC
# 288                                                   C#N
# 270459                             C1=CC(=CC=C1CC(=S)NO)O
# 158134                                           CN(C=S)O
# 364                                       C=CCC(=O)C(=O)O
# 258205                      C1=CC=C2C(=C1)C(=CN2)CC(=S)NO
# 218896  B1(C2CCCC1CCC2)[C@H]3C[C@H]4C[C@@H]([C@@H]3CCO...
# 38778                                CC(C)N(C(=O)C(=O)O)O
# 73650                                CC1=C(C=CC(=O)N1O)OC
# 1050    CC(=O)N(CCCCCNC(=O)CCC(=O)N(CCCCCNC(=O)CCC(=O)...
# 178210                          C1=CC=C(C=C1)/C=C/C(=O)NO
# 5496                                 C1=CC=C(C=C1)C(=O)NO
# 4357                                          B(OC)(OC)OC
# 268                                                   C=O
# 556                                     C1=CC(=S)N(C=C1)O
# 72275   CC(=O)N(CCC[C@H]1C(=O)N[C@H](C(=O)N[C@H](C(=O)...
# 35672                                      C(CCC(=O)N)CCN
#
#                    InChIKey_pubchem  \
# 40303   ASOKPJOREAFHNY-UHFFFAOYSA-N
# 72524   BCNUXXXHEIUHJB-UHFFFAOYSA-N
# 15950   COVOPZQGJGUPEY-UHFFFAOYSA-N
# 35975   CQJHAULYLJXJNL-UHFFFAOYSA-N
# 320975  CUJCSBFFGKTHSK-UHFFFAOYSA-N
# 318649  DKSPATNIHZSGOP-YZSKCGIOSA-N
# 830     GDNZNIJPBQATCZ-UHFFFAOYSA-N
# 37218   GPAYUJZHTULNBE-UHFFFAOYSA-N
# 161598  IHTJGIKQNHDTSX-UHFFFAOYSA-N
# 70075   KAIQUJDTIFXCLP-UHFFFAOYSA-N
# 44430   KTWCUGUUDHJVIH-UHFFFAOYSA-N
# 3380    LALRXNPLTWZJIJ-UHFFFAOYSA-N
# 288     LELOWRISYMNNSU-UHFFFAOYSA-N
# 270459  LPISVKQODWVLPO-UHFFFAOYSA-N
# 288               0.1                  27.010899
# 270459            0.9                 183.035400
# 158134           -0.2                  91.009185
# 364               0.4                 114.031694
# 258205            1.3                 206.051384
# 218896            NaN                 378.309396
# 38778             0.5                 147.053158
# 73650             0.0                 155.058243
# 1050             -2.1                 560.353363
# 178210            1.4                 163.063329
# 5496              0.3                 137.047678
# 4357              NaN                 104.064474
# 268               1.2                  30.010565
# 556               0.5                 127.009185
# 72275            -4.7                 687.318768
# 35672            -1.3                 130.110613
#
#                                                 ROMol  \
# 40303   <rdkit.Chem.rdchem.Mol object at 0x1693cf450>
# 72524   <rdkit.Chem.rdchem.Mol object at 0x14e988eb0>
# 15950   <rdkit.Chem.rdchem.Mol object at 0x14d8959a0>
# 35975   <rdkit.Chem.rdchem.Mol object at 0x300f18200>
# 320975  <rdkit.Chem.rdchem.Mol object at 0x13e478890>
# 318649  <rdkit.Chem.rdchem.Mol object at 0x13e4c46d0>
# 830     <rdkit.Chem.rdchem.Mol object at 0x1763025e0>
# 37218   <rdkit.Chem.rdchem.Mol object at 0x1693965e0>
# 161598  <rdkit.Chem.rdchem.Mol object at 0x14a3acd60>
# 70075   <rdkit.Chem.rdchem.Mol object at 0x14e9c2260>
# 44430   <rdkit.Chem.rdchem.Mol object at 0x1693087b0>
# 3380    <rdkit.Chem.rdchem.Mol object at 0x176288820>
# 288     <rdkit.Chem.rdchem.Mol object at 0x1762c83c0>
# 270459  <rdkit.Chem.rdchem.Mol object at 0x14fd33840>
# 158134  <rdkit.Chem.rdchem.Mol object at 0x1681415b0>
# 364     <rdkit.Chem.rdchem.Mol object at 0x1762c9e00>
# 258205  <rdkit.Chem.rdchem.Mol object at 0x14d171a10>
# 218896  <rdkit.Chem.rdchem.Mol object at 0x16a8da570>
# 38778   <rdkit.Chem.rdchem.Mol object at 0x1693b1540>
# 73650   <rdkit.Chem.rdchem.Mol object at 0x14e973f40>
# 1050    <rdkit.Chem.rdchem.Mol object at 0x1762c4740>
# 178210  <rdkit.Chem.rdchem.Mol object at 0x14aac6730>
# 5496    <rdkit.Chem.rdchem.Mol object at 0x16b76ec70>
# 4357    <rdkit.Chem.rdchem.Mol object at 0x17627b680>
# 268     <rdkit.Chem.rdchem.Mol object at 0x173beba70>
# 556     <rdkit.Chem.rdchem.Mol object at 0x1762fedc0>
# 72275   <rdkit.Chem.rdchem.Mol object at 0x14e9960a0>
# 35672   <rdkit.Chem.rdchem.Mol object at 0x300f27bc0>
#
#                                                    SMILES  \
# 40303                                      On1nnc2ccccc21
# 72524                                    C=C1C=Nc2ccccc21
# 15950                                O=C1C(O)Oc2ccccc2N1O
# 35975                                      CC(C)=CCC(=O)O
# 320975  CN(C)CCCN(O)S(=O)(=O)CCC(F)(F)C(F)(F)C(F)(F)C(...
# 318649  CC(=CC(=O)N(O)CCCC1NC(=O)CNC(=O)C(CO)NC(=O)C(C...
# 830                            COc1ccc2c(c1)OC(O)C(=O)N2O
# 37218                                 c1ccc(Pc2ccccc2)cc1
# 161598                                   ONC(=S)Cc1ccccc1
# 70075                         O=C(Cn1ccnc1[N+](=O)[O-])NO
# 5496    VDEUYMSGMPQMIK-UHFFFAOYSA-N  VDEUYMSGMPQMIK
# 4357    WRECIMRULFAWHA-UHFFFAOYSA-N  WRECIMRULFAWHA
# 268     WSFSSNUMVMOOMR-UHFFFAOYSA-N  WSFSSNUMVMOOMR
# 556     YBBJKCMMCRQZMA-UHFFFAOYSA-N  YBBJKCMMCRQZMA
# 72275   ZFDAUYPBCXMSBF-UHFFFAOYSA-N  ZFDAUYPBCXMSBF
# 35672   ZLHYDRXTDZFRDZ-UHFFFAOYSA-N  ZLHYDRXTDZFRDZ

# %%
pubchemlite_no_dupl = pubchemlite[~pubchemlite.InChIKey.isin(pubchemlite_dupl.InChIKey)] #Remove any duplicates from the original dataframe

pubchemlite_std = pd.concat([pubchemlite_no_dupl, pubchemlite_dupl_removed], ignore_index=True).reset_index(drop=True) #removes the duplicates from the original dataframe and appends the new ones

# %%
pubchemlite_std.shape
# Out:
# (407967, 10)

# %%
# with open('2025-04-09_PubChemLite_smiles_cleaned.pkl', 'wb') as f:
#       pickle.dump(pubchemlite, f)

# %% [markdown]
# ### Standardization of the data using the PubChem StandardUtils
#
# Divide into multiple batches to process over multiple evenings, and then add onto each other when they are all done.

# %%
with open('2025-04-09_PubChemLite_smiles_cleaned.pkl', 'rb') as f:
    pubchemlite = pickle.load(f)

# %%
pubchemlite_batches = np.array_split(pubchemlite, 4)
# Out:
# /opt/anaconda3/envs/MS2Tox_APGC/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
pubchemlite_batches[0]
# Out:
#                                         SMILES                     InChIKey  \
# 0                         O=C(O)C1=CC=CC(O)C1O  INCSWYKICIYAHB-UHFFFAOYSA-N
# 1                                      CC(O)CN  HXKKHQJGJAFBHI-UHFFFAOYSA-N
# 2                           NCC(=O)COP(=O)(O)O  HIQNVODXENYOFK-UHFFFAOYSA-N
# 3       O=[N+]([O-])c1ccc(Cl)c([N+](=O)[O-])c1  VYZAHLCBVHPDDF-UHFFFAOYSA-N
# 4                          CCC(C)(O)C(O)C(=O)O  PDGXJDXVGMHUIR-UHFFFAOYSA-N
# ...                                        ...                          ...
# 101987                    COC(=O)c1cnc(N)[nH]1  NDTWFWAWLBGFQI-UHFFFAOYSA-N
# 101988               O=C(Cn1cncn1)c1ccc(F)cc1F  XCHRPVARHBCFMJ-UHFFFAOYSA-N
# 101989                     O=C(Cl)c1ccc(F)cc1F  JSWRVDNTKPAJLB-UHFFFAOYSA-N
# 101990                     O=C(Cl)c1cc(F)ccc1F  RLRUKKDFNWXXRT-UHFFFAOYSA-N
# 101991                    O=C(CCl)c1ccc(F)cc1F  UENGBOCGGKLVJJ-UHFFFAOYSA-N
#
#                                              CompoundName  PubChem_cid  XLogP  \
# 0       5,6-dihydroxycyclohexa-1,3-diene-1-carboxylic ...            3   -0.3
# 1                                      1-aminopropan-2-ol            4   -1.0
# 2              (3-amino-2-oxopropyl) dihydrogen phosphate            5   -5.0
# 3                             1-chloro-2,4-dinitrobenzene            6    2.3
# 4                    2,3-dihydroxy-3-methylpentanoic acid            8   -0.4
# ...                                                   ...          ...    ...
# 101987          methyl 2-amino-1H-imidazole-5-carboxylate       588062   -0.1
# 101988  1-(2,4-difluorophenyl)-2-(1,2,4-triazol-1-yl)e...       588080    1.7
# 101989                       2,4-difluorobenzoyl chloride       588081    2.6
# 101990                       2,5-difluorobenzoyl chloride       588082    2.6
# 101991            2-chloro-1-(2,4-difluorophenyl)ethanone       588083    2.4
#
#         MonoisotopicMass                                          ROMol  \
# 0             156.042259  <rdkit.Chem.rdchem.Mol object at 0x169ff38d0>
# 1              75.068414  <rdkit.Chem.rdchem.Mol object at 0x169ff3920>
# 2             169.014009  <rdkit.Chem.rdchem.Mol object at 0x169ff3970>
# 3             201.978134  <rdkit.Chem.rdchem.Mol object at 0x169ff39c0>
# 4             148.073559  <rdkit.Chem.rdchem.Mol object at 0x169ff3a10>
# ...                  ...                                            ...
# 101987        141.053826  <rdkit.Chem.rdchem.Mol object at 0x32e3a74c0>
# 101988        223.055718  <rdkit.Chem.rdchem.Mol object at 0x32e3a7510>
# 101989        175.984049  <rdkit.Chem.rdchem.Mol object at 0x32e3a7560>
# 101990        175.984049  <rdkit.Chem.rdchem.Mol object at 0x32e3a75b0>
# 101991        189.999699  <rdkit.Chem.rdchem.Mol object at 0x32e3a7600>
#
#             InChIKey14
# 0       INCSWYKICIYAHB
# 1       HXKKHQJGJAFBHI
# 2       HIQNVODXENYOFK
# 3       VYZAHLCBVHPDDF
# 4       PDGXJDXVGMHUIR
# ...                ...
# 101987  NDTWFWAWLBGFQI
# 101988  XCHRPVARHBCFMJ
# 101989  JSWRVDNTKPAJLB
# 101990  RLRUKKDFNWXXRT
# 101991  UENGBOCGGKLVJJ
#
# [101992 rows x 8 columns]

# %%
pubchemlite_head = pubchemlite.head(1000)

# %%
from standardizeUtils.standardizeUtils import standardize_structure_with_pubchem
from standardizeUtils.standardizeUtils import standardize_structure_list_with_pubchem

import time
import requests  



def standardize_in_batches(smiles_list, initial_batch_size=1000):
    """
    Standardizes SMILES in batches, reducing batch size on failure.
    Input: SMILES list
    Output: Standardized SMILES list
    """
    total_smiles = len(smiles_list)
    processed_smiles = []
    idx = 0
    batch_size = initial_batch_size # Starting with 1000

    while idx < total_smiles:
        attempt_success = False
        current_batch_size = batch_size

        while current_batch_size >= 100:
            try:
                print(f"Processing batch {idx}:{idx + current_batch_size} (size={current_batch_size})")
                batch = smiles_list[idx : idx + current_batch_size]
                standardized_batch = standardize_structure_list_with_pubchem(batch, 'smiles')
                processed_smiles.extend(standardized_batch)
                idx += current_batch_size
                attempt_success = True
                break  

            except requests.exceptions.RequestException as e:
                print(f"Error occurred: {e}, reducing batch size...")
                current_batch_size //= 2  # Reduce batch size by half on failure > can be changed
                time.sleep(2)  

        if not attempt_success:
            print(f"Skipping batch {idx}:{idx + current_batch_size} due to repeated failures.")
            idx += current_batch_size  

    return processed_smiles

pubchemlite_head['std_SMILES'] = standardize_in_batches(pubchemlite_head.SMILES.to_list())
# Out:
# Processing batch 0:1000 (size=1000)
# /var/folders/0w/cl6vcbp52mjfxw4v9_2l1_780000gn/T/ipykernel_76559/4207872608.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pubchemlite_head['std_SMILES'] = standardize_in_batches(pubchemlite_head.SMILES.to_list())

# %%
pubchemlite_head[pubchemlite_head.SMILES_pubchem!=pubchemlite_head.std_SMILES][['SMILES_pubchem', 'std_SMILES']] # The SMILES from standardization and pubchem smiles might in some cases differ, standardization is therefore needed.
# Out:
#      SMILES_pubchem      std_SMILES
# 237  CN1CC(=O)N=C1N  CN1CC(=O)NC1=N

# %%
#pubchemlite_batches[0]['std_SMILES'] = standardize_in_batches(pubchemlite_batches[0].SMILES.to_list())
#pubchemlite_batches[1]['std_SMILES'] = standardize_in_batches(pubchemlite_batches[1].SMILES.to_list())
pubchemlite_batches[2]['std_SMILES'] = standardize_in_batches(pubchemlite_batches[2].SMILES.to_list())
#pubchemlite_batches[3]['std_SMILES'] = standardize_in_batches(pubchemlite_batches[3].SMILES.to_list())

with open('2025-03-19_PubChemLite_std_smiles_batch3.pkl', 'wb') as f:
    pickle.dump(pubchemlite_batches[2], f)
# Out:
# Processing batch 0:1000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Fc1ccc([BH](F)(F)F)cc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CCCCC#C[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "O=Cc1ccccc1[BH](F)(F)F".
# Processing batch 1000:2000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(=O)O[BH](OC(C)=O)OC(C)=O".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "C[BH](C)(C)C".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "c1cnn([BH](n2cccn2)n2cccn2)c1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Cc1cc(C)n([BH](n2nc(C)cc2C)n2nc(C)cc2C)n1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "C=CC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC1C([BH]2C3CCCC2CCC3)CC2CC1C2(C)C".
# Processing batch 2000:3000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)C#Cc1ccccc1".
# Processing batch 3000:4000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)CCCCl".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "C=C[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC[BH](CC)CC".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "C[Si](C)(C)C#C[BH](F)(F)F".
# Processing batch 4000:5000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)C1CC1c1ccccc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Cc1ccc(C=C[BH](F)(F)F)cc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "FC(F)(F)C(F)(F)[PH](F)(F)(F)(C(F)(F)C(F)(F)F)C(F)(F)C(F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Fc1cccc(F)c1[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)C(F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "FC(F)=C(F)[BH](F)(F)F".
# Processing batch 5000:6000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1ccc(Cl)cc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "O=C1O[BH]2(OC1=O)OC(=O)C(=O)O2".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CO[BH](OC)(OC)C(F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "O=C(O)c1cccc([BH](F)(F)F)c1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1ccc2ccccc2c1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CCCCCCCC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1cccc(C(F)(F)F)c1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Oc1ccccc1[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CCCC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1cccnc1".
# Processing batch 6000:7000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Fc1cc(F)cc([BH](F)(F)F)c1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(=O)c1ccc([BH](F)(F)F)cc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(C)(C)c1ccc([BH](F)(F)F)cc1".
# Processing batch 7000:8000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "C=Cc1ccc([BH](F)(F)F)cc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "N#CC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)CBr".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)CI".
# Processing batch 8000:9000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)C1CCCCC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "O=Cc1cc([BH](F)(F)F)cs1".
# Processing batch 9000:10000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Cc1cc(C)c(P(c2c(C)cc(C)cc2C)c2c(F)c(F)c([BH](c3c(F)c(F)c(F)c(F)c3F)c3c(F)c(F)c(F)c(F)c3F)c(F)c2F)c(C)c1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "C=C(C)[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "O=C1O[BH]2(OC(=O)c3ccccc3O2)Oc2ccccc21".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)C(F)(F)C(F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "c1cn([BH](n2ccnc2)(n2ccnc2)n2ccnc2)cn1".
# Processing batch 10000:11000 (size=1000)
# Processing batch 11000:12000 (size=1000)
# Processing batch 12000:13000 (size=1000)
# Processing batch 13000:14000 (size=1000)
# Processing batch 14000:15000 (size=1000)
# Processing batch 15000:16000 (size=1000)
# Processing batch 16000:17000 (size=1000)
# Processing batch 17000:18000 (size=1000)
# Processing batch 18000:19000 (size=1000)
# Processing batch 19000:20000 (size=1000)
# Processing batch 20000:21000 (size=1000)
# Processing batch 21000:22000 (size=1000)
# Processing batch 22000:23000 (size=1000)
# Processing batch 23000:24000 (size=1000)
# Processing batch 24000:25000 (size=1000)
# Processing batch 25000:26000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC
".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)C1CCC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(C)CC(NC(=O)CNC(=O)C(NC(=O)C(CC(N)=O)NC(=O)C(CC(N)=O)NC(=O)C(CCC(=O)O)NC(=O)C1CCCN1C(=O)C(CC(N)=O)NC(=O)C(CO)NC(=O)C(CCCN=C(N)N)NC(=O)C(NC(=O)C(CCCCN)NC(=O)C(CO)NC(=O)C(Cc1cnc[nH]1)NC(=O)C(CS)NC(=O)C(N)C(C)C)C(C)O)C(C)C)C(=O)O".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "FC(F)(F)C(O[BH](OC(C(F)(F)F)C(F)(F)F)OC(C(F)(F)F)C(F)(F)F)C(F)(F)F".
# Processing batch 54000:55000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Cc1ccc([BH](F)(F)F)o1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "O=Cc1ccc([BH](F)(F)F)o1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1ccn[nH]1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1ccncc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Fc1ncccc1[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Fc1ccc([BH](F)(F)F)cn1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "COc1ncc([BH](F)(F)F)cn1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1ccc2[nH]ccc2c1".
# Processing batch 55000:56000 (size=1000)
# Processing batch 56000:57000 (size=1000)
# Processing batch 57000:58000 (size=1000)
# Processing batch 58000:59000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(C)(C)OC(=O)NCC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "N#CCC[BH](F)(F)F".
# Processing batch 59000:60000 (size=1000)
# Processing batch 60000:61000 (size=1000)
# Processing batch 61000:62000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(c1ccccc1)[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1ccc(CN2CCOCC2)cc1".
# Processing batch 62000:63000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1cccs1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CCCCOc1ccc([BH](F)(F)F)cc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1ccccc1OCc1ccccc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Cc1cc(OCc2ccccc2)ccc1[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1ccc(Cl)c(Cl)c1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CCOC(=O)c1ccccc1[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Fc1cc(C(F)(F)F)ccc1[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1ccc(C(F)(F)F)cc1C(F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "O=[N+]([O-])c1ccc([BH](F)(F)F)cc1".
# Processing batch 63000:64000 (size=1000)
# Processing batch 64000:65000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)COc1ccccc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "O=Cc1ccc([BH](F)(F)F)s1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1cc2ccccc2s1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)CNC1CCCCC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)CN1CCOCC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(C)(C)OC(=O)N1CCN(C[BH](F)(F)F)CC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CN(C[BH](F)(F)F)C1CCCCC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "COC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CN1CCN(C[BH](F)(F)F)CC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CN(C)C[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(C)(C)OC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)COCc1ccccc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1cncnc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Cc1cc([BH](F)(F)F)c(C)s1".
# Processing batch 65000:66000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "N#Cc1ccccc1[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Oc1ccc([BH](F)(F)F)cc1".
# Processing batch 66000:67000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CCCCC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1cccc(I)c1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1ccc2nonc2c1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "O=C(c1ccc([BH](F)(F)F)cc1)N1CCOCC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CCOC(=O)c1ccc([BH](F)(F)F)cc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "COC(=O)CC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "C#C[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "O=C(Cc1ccccc1)[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1ccc(Cl)nc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "COc1ccc(COC[BH](F)(F)F)cc1".
# Processing batch 67000:68000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(C)(C)OC(=O)CC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)CC1CCCC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)CC1CCC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC=C[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(C)OC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)CC1CCCCC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CN(C)c1ccc([BH](F)(F)F)cc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1ccc(Br)s1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "COc1cc(Br)cc([BH](F)(F)F)c1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1cc(Cl)cc(Br)c1".
# Processing batch 68000:69000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "COCCC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)CC1CC1".
# Processing batch 69000:70000 (size=1000)
# Processing batch 70000:71000 (size=1000)
# Processing batch 71000:72000 (size=1000)
# Processing batch 72000:73000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1ccccn1".
# Processing batch 73000:74000 (size=1000)
# Processing batch 74000:75000 (size=1000)
# Processing batch 75000:76000 (size=1000)
# Processing batch 76000:77000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(C)(C)OC(=O)NC[BH](F)(F)F".
# Processing batch 77000:78000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "OCc1cccc([BH](F)(F)F)c1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "OC[BH](F)(F)F".
# Processing batch 78000:79000 (size=1000)
# Processing batch 79000:80000 (size=1000)
# Processing batch 80000:81000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CN(C)CCC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Nc1cccc([BH](F)(F)F)c1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)C=CC1CC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CCC(C)(C)[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)C1=CCCCC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)C1CCCOC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "N#CC1CC([BH](F)(F)F)C1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "OC1CC([BH](F)(F)F)C1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)CN1CCC1".
# Processing batch 81000:82000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "OC1CN(C[BH](F)(F)F)C1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(=O)NC1C(OC(C)C(NC(=O)C(C)NC(=O)C(CC(N)=O)NC(=O)C(CO)NC(=O)CNC(=O)CNC(=O)C(CCC(=O)O)NC(=O)C(CCC(=O)O)NC(

# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CCCCc1ccc([BH](F)(F)F)cc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1ccc2c(c1)CCO2".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CCC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Cc1ccc(C[BH](F)(F)F)cc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)Cc1ccc(C(F)(F)F)cc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "COc1cccc(C[BH](F)(F)F)c1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "COCC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(C)(C)[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)Cc1ccc(Cl)cc1Cl".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CCOCC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)Cc1ccccc1Cl".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Fc1ccc(C[BH](F)(F)F)cc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)Cn1cccn1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "O=S1(=O)CCN(C[BH](F)(F)F)CC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CCc1ccc(C[BH](F)(F)F)s1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)CC1CCOCC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)C1CCOC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)Cc1ccc(Cl)cc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Cc1cccc(C[BH](F)(F)F)c1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CN(C[BH](F)(F)F)CC(F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CCOC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)COC1CCC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)Cc1cccc(Cl)c1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "Cn1nccc1[BH](F)(F)F".
# Processing batch 91000:92000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "COCCOCC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC1CCC([BH](F)(F)F)CC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CCOCCC[BH](F)(F)F".
# Processing batch 92000:93000 (size=1000)
# Processing batch 93000:94000 (size=1000)
# Processing batch 94000:95000 (size=1000)
# Processing batch 95000:96000 (size=1000)
# Processing batch 96000:97000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "O=C(c1ccc([BH](F)(F)F)cc1)N1CCCCC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "O=C(c1cccc([BH](F)(F)F)c1)N1CCCCC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CCN(CC)C(=O)c1ccc([BH](F)(F)F)cc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "O=C(NCc1ccccc1)c1ccc([BH](F)(F)F)cc1".
# Processing batch 97000:98000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CON(C)C(=O)c1ccc([BH](F)(F)F)cc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC1(C)c2ccccc2-c2ccc([BH](F)(F)F)cc21".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "[N-]=[N+]=NCc1ccc([BH](F)(F)F)cc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "[N-]=[N+]=NCc1cccc([BH](F)(F)F)c1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "COCC=C[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC=C(C)[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "FB1C[B-]2(F)B(F)[BH](F)(B(F)B(F)B(F)B(F)B(F)B1F)B2F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1ccc(Br)nc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1cccnc1Cl".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)c1ccc(Cl)s1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(C)(C)OC(=O)n1ccc2cc([BH](F)(F)F)ccc21".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(=O)NC(CS)C(=O)NC(CO)C(=O)NC(Cc1ccccc1)C(=O)NC(C(=O)NC(CC(N)=O)C(=O)NC(CO)C(=O)NC(CCC(=O)O)C(=O)NC(Cc1ccccc1)C(=O)NC(CC(C)C)C(=O)NC(CCCCN)C(=O)N1CCCC1C(=O)NC(CCC(=O)O)C(=O)NC(C(=O)NC(CCCCN)C(=O)NC(CO)C(=O)O)C(C)C)C(C)C".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)CCOCc1ccccc1".
# Processing batch 98000:99000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(C)(C)OC(=O)N1CC([BH](F)(F)F)C1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)C1COC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(C)(C)OC(=O)N1CCC([BH](F)(F)F)CC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(C)(C)OC(=O)N1CCC([BH](F)(F)F)C1".
# Processing batch 99000:100000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)CCc1ccccn1".
# Processing batch 100000:101000 (size=1000)
# Processing batch 101000:102000 (size=1000)
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(C)C(N)C(=O)OC(C)C1CC=CCCC(O)C(C)(C)C2CCC(C)C3(O2)O[BH]24OC(C(=O)O1)C1(OC(CCC1C)C(C)(C)C(O)CCCC1CC(OC(=O)C3O2)C(C)O1)O4".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "COCCNC(=O)c1ccc([BH](F)(F)F)cc1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "COCCNC(=O)c1cccc([BH](F)(F)F)c1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "O=C(c1ccc([BH](F)(F)F)cc1)N1CCCC1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(=O)OCC[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(C)(C)OC(=O)N1CC(C[BH](F)(F)F)C1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(C)(C)OC(=O)N1CCCCC1[BH](F)(F)F".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)CC1CCCCO1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "F[BH](F)(F)CCOC1CCCCO1".
# The standardization request failed. The response contains the following "PCT-Status" tag: <PCT-Status value="data-error"/>
# An exception of class InputDataError was thrown. Return 'None' for query "CC(C)(C)OC(=O)N1CCCC1[BH](F)(F)F".

# %%
pubchemlite_batches[1][pubchemlite_batches[1].std_SMILES.isna()]
# Out:
#                                                    SMILES  \
# 118475                            [2H][BH]([2H])([2H])C#N
# 168621                  trifluoro(thiophen-3-yl)boranuide      4250938    NaN
# 168699              tetrakis(4-tert-butylphenyl)boranuide      4260042    NaN
# 169159                       difluoro(triphenyl)silanuide      4338203    NaN
# 169437      tetrakis[(2-methylquinolin-8-yl)oxy]boranuide      4362975    NaN
# 170112     tetrakis(2,3,4,5,6-pentafluorophenyl)boranuide      4438527    NaN
# 170561  8,8'-spirobi[7,9-dioxa-8-boranuidabicyclo[4.3....      4526831    NaN
# 170608                  tetrakis(3-chlorophenyl)boranuide      4534987    NaN
# 173483                  tetrakis(4-phenylphenyl)boranuide      5067832    NaN
# 174871                         trifluoro(methyl)boranuide      5257871    NaN
# 178951  (1R,2R,5S,6R,8S,9E,12R,14S,17R,18R,22R,25S,26R...      5460904    NaN
# 182270           trifluoro-[(E)-2-phenylethenyl]boranuide      6262929    NaN
# 183013                                                NaN      6390122    NaN
# 188050                                                NaN      6451856    NaN
# 188330                                                NaN      6455445    NaN
# 198389                                                NaN      9795269    NaN
# 200579  (1S,1'S,5R,5'R,7R,7'R,8S,8'S)-5,5',7,7'-tetrak...      9962299    NaN
# 200849                     trifluoro(furan-2-yl)boranuide     10012398    NaN
# 200884                trifluoro(naphthalen-1-yl)boranuide     10014233    NaN
# 200981                                tetracyanoboranuide     10034817    NaN
# 202978                trifluoro-(2-fluorophenyl)boranuide     10420368    NaN
# 203428         trifluoro-(2,4,6-trimethylphenyl)boranuide     10489405    NaN
# 203468                          butyl(triphenyl)boranuide     10508044    NaN
# 203653            (2,4-dichlorophenyl)-trifluoroboranuide     10538798    NaN
#
#         MonoisotopicMass                                          ROMol  \
# 118475         43.054685  <rdkit.Chem.rdchem.Mol object at 0x338242980>
# 125203        863.064881  <rdkit.Chem.rdchem.Mol object at 0x33ae56840>
# 125930        145.043640  <rdkit.Chem.rdchem.Mol object at 0x33b610c70>
# 125931        175.054204  <rdkit.Chem.rdchem.Mol object at 0x33b610cc0>
# 125932        159.059290  <rdkit.Chem.rdchem.Mol object at 0x33b610d10>
# 125933        193.044783  <rdkit.Chem.rdchem.Mol object at 0x33b610d60>
# 125934        175.054204  <rdkit.Chem.rdchem.Mol object at 0x33b610db0>
# 125935        223.021190  <rdkit.Chem.rdchem.Mol object at 0x33b610e00>
# 125936        238.032089  <rdkit.Chem.rdchem.Mol object at 0x33b610e50>
# 125937        179.004668  <rdkit.Chem.rdchem.Mol object at 0x33b610ea0>
# 125938        196.995246  <rdkit.Chem.rdchem.Mol object at 0x33b610ef0>
# 125939        251.085505  <rdkit.Chem.rdchem.Mol object at 0x33b610f40>
# 125940        173.038554  <rdkit.Chem.rdchem.Mol object at 0x33b610f90>
# 125941        251.085505  <rdkit.Chem.rdchem.Mol object at 0x33b610fe0>
# 125942        170.038889  <rdkit.Chem.rdchem.Mol object at 0x33b611030>
# 125943        159.059290  <rdkit.Chem.rdchem.Mol object at 0x33b611080>
# 125944        190.028718  <rdkit.Chem.rdchem.Mol object at 0x33b6110d0>
# 125945        175.054204  <rdkit.Chem.rdchem.Mol object at 0x33b611120>
# 125946        223.021190  <rdkit.Chem.rdchem.Mol object at 0x33b611170>
# 125947        189.033469  <rdkit.Chem.rdchem.Mol object at 0x33b6111c0>
# 125948        170.038889  <rdkit.Chem.rdchem.Mol object at 0x33b611210>
# 128149        259.129420  <rdkit.Chem.rdchem.Mol object at 0x33c6204a0>
# 161417        173.074940  <rdkit.Chem.rdchem.Mol object at 0x3532489a0>
# 161568        281.018409  <rdkit.Chem.rdchem.Mol object at 0x35324b8d0>
# 162425        159.059290  <rdkit.Chem.rdchem.Mol object at 0x353b485e0>
# 163024        222.954150  <rdkit.Chem.rdchem.Mol object at 0x353bc81d0>
# 163307        159.059290  <rdkit.Chem.rdchem.Mol object at 0x354411a80>
# 163497        213.031024  <rdkit.Chem.rdchem.Mol object at 0x354439620>
# 166516        342.991490  <rdkit.Chem.rdchem.Mol object at 0x356710950>
# 167415        173.074940  <rdkit.Chem.rdchem.Mol object at 0x3567d2340>
# 168621        151.000061  <rdkit.Chem.rdchem.Mol object at 0x3570fdda0>
# 168699        543.416207  <rdkit.Chem.rdchem.Mol object at 0x3570ff600>
# 169159        297.091108  <rdkit.Chem.rdchem.Mol object at 0x357880680>
# 169437        643.251661  <rdkit.Chem.rdchem.Mol object at 0x3578c1da0>
# 170112        678.977368  <rdkit.Chem.rdchem.Mol object at 0x35804f150>
# 170561        227.051564  <rdkit.Chem.rdchem.Mol object at 0x3580abe20>
# 170608        455.009916  <rdkit.Chem.rdchem.Mol object at 0x3580e8d10>
# 173483        623.291006  <rdkit.Chem.rdchem.Mol object at 0x359b85300>
# 174871         83.027990  <rdkit.Chem.rdchem.Mol object at 0x35a4d0680>
# 178951        775.407612  <rdkit.Chem.rdchem.Mol object at 0x35da8c680>
# 182270        171.059290  <rdkit.Chem.rdchem.Mol object at 0x35fa957b0>
# 183013        242.126681  <rdkit.Chem.rdchem.Mol object at 0x36044c0e0>
# 188050        188.158375  <rdkit.Chem.rdchem.Mol object at 0x362de6cf0>
# 188330        182.220581  <rdkit.Chem.rdchem.Mol object at 0x3640384f0>
# 198389        224.267531  <rdkit.Chem.rdchem.Mol object at 0x36a6818a0>
# 200579        367.104781  <rdkit.Chem.rdchem.Mol object at 0x36bc9c7c0>
# 200849        135.022904  <rdkit.Chem.rdchem.Mol object at 0x36bcc5c60>
# 200884        195.059290  <rdkit.Chem.rdchem.Mol object at 0x36bcc6750>
# 200981        115.021601  <rdkit.Chem.rdchem.Mol object at 0x36bcf45e0>
# 202978        163.034218  <rdkit.Chem.rdchem.Mol object at 0x36cf97830>
# 203428        187.090590  <rdkit.Chem.rdchem.Mol object at 0x36d830590>
# 203468        299.197106  <rdkit.Chem.rdchem.Mol object at 0x36d831210>
# 203653        212.965695  <rdkit.Chem.rdchem.Mol object at 0x36d860c20>
#
#             InChIKey14 std_SMILES
# 118475  BBWWRPHGUGQYTM       None
# 125203  LSJLFVQOCPUFMW       None
# 125930  TWOKLPOPVVGTTR       None
# 125931  UMTMKESCTWSUTC       None
# 125932  ZMZPFKAYZNLWMF       None
# 125933  ZRSQBNZILRUUOM       None
# 125934  ZBWDBWABYIOLLG       None
# 125935  VUPYXBLIMCNRBG       None
# 125936  ZKTVPPQABWFBNG       None
# 125937  UBLNYMJDVJUGMF       None
# 125938  PYSHBDBVIAZLKF       None
# 125939  NMKDXPXZRPKPBW       None
# 125940  FLDKJABUYNMUHI       None
# 125941  RYOIHHJCZQDVDA       None
# 125942  NFBPOAOZXVIXIL       None
# 125943  RTUWHCZLQDRSRX       None
# 125944  OBWIEEZEFGEZEE       None
# 125945  BGXATDISPORZHN       None
# 125946  DDBUKCGMESOFFS       None
# 125947  HCSOMOLTCCHVMV       None
# 125948  BIXJVOJSHYIXKF       None
# 128149  YEDGYZSMOCKUCJ       None
# 161417  WKACSGXXZZRISM       None
# 161568  XAVNRRLYBAITGY       None
# 162425  UKBQFJBBVXKDDO       None
# 163024  YMVWOQUXDDFOBT       None
# 163307  DIYPXZNUOIUPDP       None
# 163497  XTOQWCMYWRCJES       None
# 166516  USFVMKWFUQSLBH       None
# 167415  NXOXPLHNLNXCNM       None
# 168621  AFDTVFCVYYNDIB       None
# 168699  JTGPWNVDGQQQKJ       None
# 169159  HFBIKZKZIPHPJV       None
# 169437  QEATWEVNWICTIZ       None
# 170112  KCGFEENXMWJMGN       None
# 170561  QHSHIQGXYQLTMF       None
# 170608  OQSKXOWUDOZKQN       None
# 173483  MWBQYNHZPQKGPQ       None
# 174871  KCBLXHVEGWJRPI       None
# 178951  WIMFCZCBWJVLSS       None
# 182270  OXEJQRPMLAEDJD       None
# 183013  CLNSKJYVEJHFQB       None
# 188050  BPRPBUVTEHAJGN       None
# 188330  UVJJRFJWDLHFRY       None
# 198389  QGGIQXSKKGLXJM       None
# 200579  BBFKVUKHJLAQFB       None
# 200849  DODXNGVKIKNDLI       None
# 200884  LOTSKYQSVZHWNZ       None
# 200981  PISJMCJSWVQWGE       None
# 202978  ZOOSGYYHTWMOFC       None
# 203428  WDJAZEFOMRKLOE       None
# 203468  LSXOWWOOTZZODB       None
# 203653  BYMSVRSQBMHOHF       None

# %% [markdown]
# ### Connection to terminal to make fingerprints from the SMILES
#
# Will connect to the SIRIUS CLI to use the fingerprinter function, that will convert the standardized SMILES to fingerprints.
#
# Code made by Assist. Prof. Ida Rahu.

# %%
import subprocess

import pandas as pd
import numpy as np

import requests

email = 'ellinor.samuelsson-hoppe@su.se'
password = 'Canmake123321?'

#subprocess.run('/Applications/sirius.app/Contents/MacOS/sirius') #added to work with sirius command

process = subprocess.Popen(['/Applications/sirius.app/Contents/MacOS/sirius', 'login', '-u', email, '-p'], 
                           stdout=subprocess.PIPE, 
                           stderr=subprocess.PIPE,
                           stdin=subprocess.PIPE,
                           text=True)

process.communicate(input=password + '\n')

stdout, stderr = process.communicate()
print('STDOUT:\n', stdout)
print('STDERR:\n', stderr)

path = '/Users/elli/Library/CloudStorage/OneDrive-Kruvelab/Ellinor - Master thesis/Data/PubChemLite/'

smiles_file = path + '\\.tsv'
output_file = path + '\\.tsv'
fp_version_file = path + '\\.tsv'
charge = 1 # 1 for ESI+/ -1 for ESI-
command = ['/Applications/sirius.app/Contents/MacOS/sirius', '-i', smiles_file, 'fingerprinter', '--charge', str(charge), '-o', output_file, '-v', fp_version_file]

result = subprocess.run(command, capture_output=True, text=True)

print('STDOUT:\n', result.stdout)
print('STDERR:\n', result.stderr)
# Out:
# STDOUT:
#  Enter value for --password (Console password input.):
# Active Subscription is: 'sub|adc29910-cf73-11ec-9d64-0242ac120002 - Academic License'.
# Login successful!
#
# STDERR:
#  Mar 12, 2025 3:18:15 PM org.apache.commons.beanutils.FluentPropertyBeanIntrospector introspect
# INFO: Error when creating PropertyDescriptor for public final void org.apache.commons.configuration2.AbstractConfiguration.setProperty(java.lang.String,java.lang.Object)! Ignoring this property.
# Mar 12, 2025 3:18:16 PM de.unijena.bioinf.ms.frontend.core.ApplicationCore <clinit>
# INFO: Sirius Workspace Successfull initialized at: /Users/elli/.sirius-5.8
# Mar 12, 2025 3:18:16 PM de.unijena.bioinf.ms.frontend.core.ApplicationCore <clinit>
# INFO: You run SIRIUS 5.8.7-SNAPSHOT on mac os x_x86_64
# Mar 12, 2025 3:18:16 PM de.unijena.bioinf.ms.frontend.core.ApplicationCore <clinit>
# INFO: You run SIRIUS in 'CLI' mode.
# Mar 12, 2025 3:18:16 PM de.unijena.bioinf.ms.frontend.core.ApplicationCore <clinit>
# INFO: Sirius was compiled with the following ILP solvers: GLPK-v1.7.0 (included), Gurobi-v9.1.1, CPLEX-v12.7.1, COIN-OR-v2.10.8.4
# Mar 12, 2025 3:18:16 PM de.unijena.bioinf.ms.frontend.core.ApplicationCore <clinit>
# INFO: Treebuilder priorities loaded from 'sirius.properties' are: [CLP, GUROBI, CPLEX]
# Mar 12, 2025 3:18:16 PM de.unijena.bioinf.ms.frontend.core.ApplicationCore <clinit>
# INFO: CPU check done. 4 cores that handle 8 threads were found.
# Mar 12, 2025 3:18:17 PM de.unijena.bioinf.ChemistryBase.jobs.SiriusJobs getGlobalJobManager
# INFO: Job manager successful initialized with 6 CPU thread(s) and 4 IO thread(s).
# Mar 12, 2025 3:18:17 PM de.unijena.bioinf.rest.ProxyManager decorateWithPoolSettings
# INFO: Starting http Client with MaxPerRoute=3 / maxTotal=5 (CPU-Threads=6).
# Mar 12, 2025 3:18:21 PM de.unijena.bioinf.ms.frontend.core.ApplicationCore <clinit>
# INFO: Web API initialized.
# Mar 12, 2025 3:18:23 PM de.unijena.bioinf.ms.frontend.SiriusCLIApplication lambda$configureShutDownHook$1
# INFO: CLI shut down hook: SIRIUS is cleaning up threads and shuts down...
#
# STDOUT:
#
# STDERR:
#  Mar 12, 2025 3:18:25 PM org.apache.commons.beanutils.FluentPropertyBeanIntrospector introspect
# INFO: Error when creating PropertyDescriptor for public final void org.apache.commons.configuration2.AbstractConfiguration.setProperty(java.lang.String,java.lang.Object)! Ignoring this property.
# Mar 12, 2025 3:18:26 PM de.unijena.bioinf.ms.frontend.core.ApplicationCore <clinit>
# INFO: Sirius Workspace Successfull initialized at: /Users/elli/.sirius-5.8
# Mar 12, 2025 3:18:26 PM de.unijena.bioinf.ms.frontend.core.ApplicationCore <clinit>
# INFO: You run SIRIUS 5.8.7-SNAPSHOT on mac os x_x86_64
# Mar 12, 2025 3:18:26 PM de.unijena.bioinf.ms.frontend.core.ApplicationCore <clinit>
# INFO: You run SIRIUS in 'CLI' mode.
# Mar 12, 2025 3:18:26 PM de.unijena.bioinf.ms.frontend.core.ApplicationCore <clinit>
# INFO: Sirius was compiled with the following ILP solvers: GLPK-v1.7.0 (included), Gurobi-v9.1.1, CPLEX-v12.7.1, COIN-OR-v2.10.8.4
# Mar 12, 2025 3:18:26 PM de.unijena.bioinf.ms.frontend.core.ApplicationCore <clinit>
# INFO: Treebuilder priorities loaded from 'sirius.properties' are: [CLP, GUROBI, CPLEX]
# Mar 12, 2025 3:18:26 PM de.unijena.bioinf.ms.frontend.core.ApplicationCore <clinit>
# INFO: CPU check done. 4 cores that handle 8 threads were found.
# Mar 12, 2025 3:18:27 PM de.unijena.bioinf.ChemistryBase.jobs.SiriusJobs getGlobalJobManager
# INFO: Job manager successful initialized with 6 CPU thread(s) and 4 IO thread(s).
# Mar 12, 2025 3:18:27 PM de.unijena.bioinf.rest.ProxyManager decorateWithPoolSettings
# INFO: Starting http Client with MaxPerRoute=3 / maxTotal=5 (CPU-Threads=6).
# Mar 12, 2025 3:18:30 PM de.unijena.bioinf.ms.frontend.core.ApplicationCore <clinit>
# INFO: Web API initialized.
# Mar 12, 2025 3:18:31 PM de.unijena.bioinf.ms.frontend.Run parseArgs
# INFO: Running with following arguments: [-i, /Users/elli/Library/CloudStorage/OneDrive-Kruvelab/Ellinor - Master thesis/Data/Tox21/2025-03-12_tox21_std_smiles.tsv, fingerprinter, --charge, 1, -o, /Users/elli/Library/CloudStorage/OneDrive-Kruvelab/Ellinor - Master thesis/Data/Tox21/2025-03-12_tox21_sirius_fp.tsv, -v, /Users/elli/Library/CloudStorage/OneDrive-Kruvelab/Ellinor - Master thesis/Data/Tox21/2025-03-12_fp_description.tsv]
# Mar 12, 2025 3:18:31 PM de.unijena.bioinf.jjobs.JJob lambda$logDebug$13
# FINE: <0>[InputExpanderJJob-0] Running post processing
# Mar 12, 2025 3:18:31 PM de.unijena.bioinf.jjobs.JJob lambda$logDebug$13
# FINE: <0>[InputExpanderJJob-0] Running cleanup
# Mar 12, 2025 3:18:31 PM de.unijena.bioinf.jjobs.JJob lambda$logInfo$9
# INFO: <1>[InputExpanderJJob-1] Expanding Input Files: '/Users/elli/Library/CloudStorage/OneDrive-Kruvelab/Ellinor - Master thesis/Data/Tox21/2025-03-12_tox21_std_smiles.tsv'...
# Mar 12, 2025 3:18:31 PM de.unijena.bioinf.jjobs.JJob lambda$logInfo$9
# INFO: <1>[InputExpanderJJob-1] ...Input Files successfully expanded!
# Mar 12, 2025 3:18:31 PM de.unijena.bioinf.jjobs.JJob lambda$logDebug$13
# FINE: <1>[InputExpanderJJob-1] Running post processing
# Mar 12, 2025 3:18:31 PM de.unijena.bioinf.jjobs.JJob lambda$logDebug$13
# FINE: <1>[InputExpanderJJob-1] Running cleanup
# Mar 12, 2025 3:24:34 PM de.unijena.bioinf.ms.frontend.subtools.fingerprinter.FingerprinterWorkflow run
# INFO: DONE!
# Mar 12, 2025 3:24:34 PM de.unijena.bioinf.ms.frontend.subtools.fingerprinter.FingerprinterWorkflow run
# INFO: Following smiles could not be computed:
# Mar 12, 2025 3:24:34 PM de.unijena.bioinf.ms.frontend.subtools.fingerprinter.FingerprinterWorkflow run
# INFO: std_SMILES: java.lang.RuntimeException: org.openscience.cdk.exception.InvalidSmilesException: could not parse 'std_SMILES', unexpected character:
# std_SMILES
#  ^
# Mar 12, 2025 3:24:34 PM de.unijena.bioinf.ms.frontend.subtools.fingerprinter.FingerprinterWorkflow run
# INFO: "": java.lang.RuntimeException: org.openscience.cdk.exception.InvalidSmilesException: could not parse '""', unexpected character:
# ""
# ^
# Mar 12, 2025 3:24:34 PM de.unijena.bioinf.ms.frontend.subtools.fingerprinter.FingerprinterWorkflow run
# INFO: Writing fingerprint definition file to '/Users/elli/Library/CloudStorage/OneDrive-Kruvelab/Ellinor - Master thesis/Data/Tox21/2025-03-12_fp_description.tsv'...
# Mar 12, 2025 3:24:35 PM de.unijena.bioinf.ms.frontend.SiriusCLIApplication lambda$configureShutDownHook$1
# INFO: CLI shut down hook: SIRIUS is cleaning up threads and shuts down...
# Mar 12, 2025 3:24:35 PM de.unijena.bioinf.webapi.WebAPI shutdown
# INFO: Try to delete leftover jobs on web server...
#
#
# Please cite the following publications when using our tool:
#
# When using the SIRIUS Software please cite the following paper:
#
# Kai Dührkop, Markus Fleischauer, Marcus Ludwig, Alexander A. Aksenov, Alexey V. Melnik, Marvin Meusel, Pieter C. Dorrestein, Juho Rousu and Sebastian Böcker
# SIRIUS4: a rapid tool for turning tandem mass spectra into metabolite structure information
# Nat Methods, 16, 2019.  https://doi.org/10.1038/s41592-019-0344-8
#
#
# Depending on the tools you have used please also cite:
#
# Kai Dührkop, Louis-Félix Nothias, Markus Fleischauer, Raphael Reher, Marcus Ludwig, Martin A. Hoffmann, Daniel Petras, William H. Gerwick, Juho Rousu, Pieter C. Dorrestein and Sebastian Böcker
# Systematic classification of unknown metabolites using high-resolution fragmentation mass spectra
# Nature Biotechnology, 2020.  https://doi.org/10.1038/s41587-020-0740-8
# (Cite if you are using: CANOPUS)
#
# Yannick Djoumbou Feunang, Roman Eisner, Craig Knox, Leonid Chepelev, Janna Hastings, Gareth Owen, Eoin Fahy, Christoph Steinbeck, Shankar Subramanian, Evan Bolton, Russell Greiner, David S. Wishart
# ClassyFire: automated chemical classification with a comprehensive, computable taxonomy
# J Cheminf, 8, 2016.  https://doi.org/10.1186/s13321-016-0174-y
# (Cite if you are using: CANOPUS)
#
# Kim, Hyun Woo and Wang, Mingxun and Leber, Christopher A. and Nothias, Louis-Félix and Reher, Raphael and Kang, Kyo Bin and van der Hooft, Justin J. J. and Dorrestein, Pieter C. and Gerwick, William H. and Cottrell, Garrison W.
# NPClassifier: A Deep Neural Network-Based Structural Classification Tool for Natural Products
# Journal of Natural Products, 84, 2021.  https://doi.org/10.1021/acs.jnatprod.1c00399
# (Cite if you are using: CANOPUS)
#
# Kai Dührkop, Huibin Shen, Marvin Meusel, Juho Rousu and Sebastian Böcker
# Searching molecular structure databases with tandem mass spectra using CSI:FingerID
# Proc Natl Acad Sci U S A, 112, 2015.  https://doi.org/10.1073/pnas.1509788112
# (Cite if you are using: CSI:FingerID)
#
# Martin A. Hoffmann and Louis-Félix Nothias and Marcus Ludwig and Markus Fleischauer and Emily C. Gentry and Michael Witting and Pieter C. Dorrestein and Kai Dührkop and Sebastian Böcker
# Assigning confidence to structural annotations from mass spectra with COSMIC
# bioRxiv, 2021.  https://doi.org/10.1101/2021.03.18.435634
# (Cite if you are using: CSI:FingerID, COSMIC)
#
# Sebastian Böcker and Kai Dührkop
# Fragmentation trees reloaded
# J Cheminform, 8, 2016.  https://doi.org/10.1186/s13321-016-0116-8
# (Cite if you are using: Fragmentation Trees)
#
# Sebastian Böcker, Matthias Letzel, Zsuzsanna Lipták and Anton Pervukhin
# SIRIUS: Decomposing isotope patterns for metabolite identification
# Bioinformatics, 25, 2009.  https://doi.org/10.1093/bioinformatics/btn603
# (Cite if you are using: Isotope Pattern analysis)
#
# Marcus Ludwig, Louis-Félix Nothias, Kai Dührkop, Irina Koester, Markus Fleischauer, Martin A. Hoffmann, Daniel Petras, Fernando Vargas, Mustafa Morsy, Lihini Aluwihare, Pieter C. Dorrestein, Sebastian Böcker
# ZODIAC: database-independent molecular formula annotation using Gibbs sampling reveals unknown small molecules
# bioRxiv, 2019.  https://doi.org/10.1101/842740
# (Cite if you are using: ZODIAC)

# %%
with open('2025-03-12_PubChemLite_cleaned_smiles.pkl', 'wb') as f:
    pickle.dump(pubchemlite_subset, f)
